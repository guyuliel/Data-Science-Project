# %% [markdown]
# <table>
#   <tr>
#     <td>Guy Uliel</td>
#     <td>Rotem Dahan</td>
#   </tr>
#   <tr>
#     <td>318439908</td>
#     <td>316222215</td>
#   </tr>
# </table>

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import calendar

# %% [markdown]
# ## Scraping Data
# ##### We will insert the data into a list of dictionaries - each dictionary in the list represent an ad

# %%
def get_html(url):  # function that gets an HTML and response it back (Unreadable)
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes
        return response.text
    except requests.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        return None

def get_ad_urls(url):  # function that gets a URL (page) and for each page find all the URL ads and save them in a list
    try:
        html_content = get_html(url)
        if html_content is None:
            return []
        soup = BeautifulSoup(html_content, 'html.parser')
        cards = soup.find_all('div', class_='card-block')

        ad_urls = []
        for card in cards:
            # Stop processing once we reach the footer section
            if card.find_parent('footer'):
                break
            ad_url_tag = card.find('a', href=True)
            if ad_url_tag:
                ad_urls.append('https://www.ad.co.il' + ad_url_tag['href'])

        return ad_urls
    except Exception as e:
        print(f"Error parsing ad URLs from {url}: {e}")
        return []

def data_scrape(url):  # function that gets a URL and scrapes all the relevant data into a dictionary
    try:
        html_content = get_html(url)
        if html_content is None:
            return {}
        soup = BeautifulSoup(html_content, 'html.parser')

        # Initialize the dictionary with all possible keys and default value 'NA'
        vehicle_data = {
            'manufactor': 'NA',
            'Year': 'NA',
            'model': 'NA',
            'Hand': 'NA',
            'Gear': 'NA',
            'Engine_capacity': 'NA',
            'Engine_type': 'NA',
            'Prev_ownership': 'NA',
            'Curr_ownership': 'NA',
            'Area': 'NA',
            'City': 'NA',
            'Price': 'NA',
            'Pic_num': 'NA',
            'Cre_date': 'NA',
            'Repub_date': 'NA',
            'Description': 'NA',
            'Color': 'NA',
            'Km': 'NA',
            'Test': 'NA',
            'Supply_score':'NA'
        }

        # Mapping from Hebrew keys to English keys
        key_mapping = {
            'יצרן': 'manufactor',
            'שנה': 'Year',
            'דגם': 'model',
            'יד': 'Hand',
            'ת. הילוכים': 'Gear',
            'נפח': 'Engine_capacity',
            'סוג מנוע': 'Engine_type',
            'בעלות קודמת': 'Prev_ownership',
            'בעלות נוכחית': 'Curr_ownership',
            'אזור': 'Area',
            'עיר': 'City',
            'מחיר': 'Price',
            'מספר תמונות': 'Pic_num',
            'תאריך יצירה': 'Cre_date',
            'תאריך הקפצה אחרון': 'Repub_date',
            'תיאור': 'Description',
            'צבע': 'Color',
            'ק"מ': 'Km',
            'טסט עד': 'Test',
        }

        # Extract details from the table
        try:
            table = soup.find('table', class_='table table-sm mb-4')
            rows = table.find_all('tr')
            for row in rows:
                key_element = row.find_all('td')[0]
                value_element = row.find_all('td')[1]
                key = key_element.text.strip()
                value = value_element.text.strip()
                if key_mapping[key] in ['Km', 'Engine_capacity']:
                    value = value.replace(',', '')
                vehicle_data[key_mapping[key]] = value
        except AttributeError:
            print(f"Table not found on page {url}")

        # Extract manufacturer, model and price
        try:
            card_body = soup.find('div', class_='card-body p-3')
            if card_body:
                titles = card_body.find_all('h2', class_='card-title')
                if len(titles) >= 2:
                    title_text = titles[0].text.strip()
                    price_text = titles[1].text.strip()
                    # Assuming the title contains the manufacturer and model
                    title_parts = title_text.split()
                    if len(title_parts) >= 2:
                        vehicle_data['manufactor'] = title_parts[0]  # Assuming the first word is the manufacturer
                        vehicle_data['model'] = ' '.join(title_parts[1:])  # The rest is the model
                    vehicle_data['Price'] = price_text.replace('₪', '').replace(',', '').strip()  # Remove the currency symbol, commas, and whitespace
        except AttributeError:
            print(f"Card body not found on page {url}")

        # Count the number of images in the gallery
        try:
            gallery_div = soup.find('div', class_='col-12 d-flex mt-3 justify-content-center flex-wrap', itemscope=True)
            if gallery_div:
                images = gallery_div.find_all('img')
                vehicle_data['Pic_num'] = len(images)
            else:
                vehicle_data['Pic_num'] = 0
        except AttributeError:
            print(f"Gallery not found on page {url}")

        # Extract creation date and last bump date
        try:
            date_divs = soup.find_all('div', class_='px-3')
            if date_divs:
                for date_div in date_divs:
                    text = date_div.text.strip()
                    if 'תאריך יצירה' in text:
                        vehicle_data['Cre_date'] = text.split(':')[-1].strip()
                    elif 'תאריך הקפצה אחרון' in text:
                        vehicle_data['Repub_date'] = text.split(':')[-1].strip()
        except AttributeError:
            print(f"Date divs not found on page {url}")

        # Extract description and clean it up
        try:
            meta_description = soup.find('meta', attrs={'name': 'description'})
            if meta_description and 'content' in meta_description.attrs:
                description = meta_description['content'].strip()
                # Clean up the description by replacing newline characters with spaces and reducing multiple spaces to a single space
                clean_description = ' '.join(description.split())
                vehicle_data['Description'] = clean_description
        except AttributeError:
            print(f"Meta description not found on page {url}")

        # Convert 'Test' date to days until the last day of the month
        try:
            test_date_str = vehicle_data['Test']
            if test_date_str != 'NA':
                test_date = datetime.strptime(test_date_str, '%m/%Y')
                last_day_of_month = datetime(test_date.year, test_date.month, calendar.monthrange(test_date.year, test_date.month)[1])
                days_until_last_day = (last_day_of_month - datetime.now()).days
                vehicle_data['Test'] = days_until_last_day
        except ValueError:
            vehicle_data['Test'] = 'Invalid date'

        return vehicle_data
    except Exception as e:
        print(f"Error scraping data from {url}: {e}")
        return {}

def get_next_page_url(soup):  # function that gets the next page URL
    try:
        next_page_tag = soup.find('li', class_='nextPage')
        if next_page_tag:
            next_page_link = next_page_tag.find('a', href=True)
            if next_page_link and 'href' in next_page_link.attrs:
                return 'https://www.ad.co.il' + next_page_link['href']
        return None
    except Exception as e:
        print(f"Error finding next page URL: {e}")
        return None

# %%
base_url = 'https://www.ad.co.il/car?sp261=13905'  # URL for Mitsubishi cars
url = base_url
mitsu = [] # the list of the dictionaries - each dictionary is an ad

while url != None:
    html_content = get_html(url) # we get the html file (unreadble) by using the function 'get_html'
    soup = BeautifulSoup(html_content, 'html.parser') # make it readable( HTML document) 
    ad_urls = get_ad_urls(url) # we get into list all the urls of the page i

    for ad_url in ad_urls:
        vehicle_data = data_scrape(ad_url) # we scrape each ad for page i (as a dictionary)
        mitsu.append(vehicle_data) # we add it into the list 
    # Get the URL of the next page
    url = get_next_page_url(soup) # we change the value of the url to be index + 1 (next page) 
    # And we go back to the while loop to do the same as we did - with the next page

# %%
mitsu
# Out:
# [{'manufactor': 'מיצובישי',
#   'Year': '2005',
#   'model': 'לנסר קלאסיק',
#   'Hand': '8',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ירושלים והסביבה',
#   'City': 'ירושלים',
#   'Price': '4700',
#   'Pic_num': 3,
#   'Cre_date': '22/05/2024',
#   'Repub_date': '27/05/2024',
#   'Description': 'רכב במצב פצצה שירת אותי נאמנה הוחלף לפני חודש תושבות מנוע פלאגים ברקסים צלחות רפידות עבר טיפול 10000 ממש לאחרונה מזגן מקפיא רכב במצב מצוין פשוט תדלק וסע גמיש מע...',
#   'Color': 'כסוף',
#   'Km': '230000',
#   'Test': 141,
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'GT3000',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'חיפה וחוף הכרמל',
#   'City': 'נשר',
#   'Price': '92000',
#   'Pic_num': 4,
#   'Cre_date': '05/05/2024',
#   'Repub_date': '05/05/2024',
#   'Description': 'אאוטלנדר המפואר פרמיום 7 מקומות טופל אצל היבואן שמור מאוד ללא תקלות ללא תאונות מרווח מאוד',
#   'Color': 'לבן',
#   'Km': '141000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'I-MIEV',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'חיפה וחוף הכרמל',
#   'City': 'נשר',
#   'Price': '92000',
#   'Pic_num': 4,
#   'Cre_date': '05/05/2024',
#   'Repub_date': '04/05/2024',
#   'Description': 'אאוטלנדר הדגם המפואר 7 מקומות שמור ומטופל אצל היבואן ללא תאונות ללא תקלות רכב נח ומרווח מאוד גמיש מעט במחיר',
#   'Color': 'לבן',
#   'Km': '141000',
#   'Test': 261,
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'אקליפס',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'ליסינג',
#   'Curr_ownership': 'פרטית',
#   'Area': 'חיפה וחוף הכרמל',
#   'City': 'טירת כרמל',
#   'Price': '85000',
#   'Pic_num': 3,
#   'Cre_date': '25/04/2024',
#   'Repub_date': '25/04/2024',
#   'Description': 'מיצובישי ASX 76,000 ק"מ מוכן גם להחליף.',
#   'Color': 'שחור',
#   'Km': '76000',
#   'Test': 110,
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2010',
#   'model': 'לנסר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'נתניה והסביבה',
#   'City': 'נתניה',
#   'Price': '10000',
#   'Pic_num': 7,
#   'Cre_date': '16/03/2024',
#   'Repub_date': '16/03/2024',
#   'Description': 'גיר מנוע תקינים מעככת מוביליין רכב 7 שנים עצלי ללא בעיה .',
#   'Color': 'כסוף',
#   'Km': '242000',
#   'Test': 171,
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2022',
#   'model': 'אקליפס',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'נס ציונה - רחובות',
#   'City': 'רחובות',
#   'Price': '129000',
#   'Pic_num': 6,
#   'Cre_date': '06/02/2024',
#   'Repub_date': '06/02/2024',
#   'Description': 'דגם executive מנוע 1.5 טורבו מפתח חכם כניסה והתנעה טסט וטיפול עד 7/2024 רכב נקי מתאונות עדיין באחריות יצרן!',
#   'Color': 'כחול מטאלי',
#   'Km': '21500',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'באר שבע והסביבה',
#   'City': 'באר שבע',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'חדרה וישובי עמק חפר',
#   'City': 'חדרה',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'באר שבע והסביבה',
#   'City': 'דימונה',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ירושלים והסביבה',
#   'City': 'ירושלים',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'עכו - נהריה',
#   'City': 'נהריה',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'ראשון לציון',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'רעננה - כפר סבא',
#   'City': 'כפר סבא',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'פתח תקוה והסביבה',
#   'City': 'פתח תקווה',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'נתניה והסביבה',
#   'City': 'נתניה',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'לנסר ספורטבק',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '4200',
#   'Engine_type': 'גז',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'רעננה - כפר סבא',
#   'City': 'כפר סבא',
#   'Price': '35000',
#   'Pic_num': 4,
#   'Cre_date': '05/01/2024',
#   'Repub_date': '05/01/2024',
#   'Description': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...',
#   'Color': 'לבן',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'חיפה וחוף הכרמל',
#   'City': 'חיפה',
#   'Price': '7500',
#   'Pic_num': 6,
#   'Cre_date': '06/11/2023',
#   'Repub_date': '17/12/2023',
#   'Description': 'לרציניים בלבד!! מוכר את הרכב שלי בצער רב. האוטו ללא תאונות יש לו מצבר+אלטרנטור חדשים עם ביטוח, מזגן עובד קור וחום אפשר להתחבר למערכת גם עם כבל USB ויש רמקולים ...',
#   'Color': 'כחול',
#   'Km': '237000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2019',
#   'model': 'אקליפס',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'ראשון לציון',
#   'Price': '12000',
#   'Pic_num': 2,
#   'Cre_date': '28/11/2023',
#   'Repub_date': '28/11/2023',
#   'Description': 'מיציבושי אאוטלנדר דגם אינסטיל. 7 מקומות. ללא תאונות. גגון. כספת',
#   'Color': 'לבן שנהב',
#   'Km': '29000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2011',
#   'model': 'לנסר איוולושן',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'גליל ועמקים',
#   'City': 'נצרת עילית',
#   'Price': '13000',
#   'Pic_num': 4,
#   'Cre_date': '16/11/2023',
#   'Repub_date': '16/11/2023',
#   'Description': 'רכב כמו חדש , מצויין , חיסכוני , טסט עד 05/2024 170,000 ק״ם',
#   'Color': 'שחור',
#   'Km': '170000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2014',
#   'model': "אטראז'",
#   'Hand': '5',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'מודיעין והסביבה',
#   'City': 'מודיעין מכבים רעות',
#   'Price': '16000',
#   'Pic_num': 5,
#   'Cre_date': '23/10/2023',
#   'Repub_date': '25/10/2023',
#   'Description': 'רכב במצב מעולה כמו חדש. אמין,לא רואה מוסך,חסכוני בדלק. לאחר טיפול תקופתי מקיף,מצבר חדש,צמיגים חדשים. תא מטען ענק ,מזגן מקפיא. טסט עד פברואר. מחירון לוי יצחק 19,...',
#   'Color': 'לבן פנינה',
#   'Km': '193000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2018',
#   'model': "אטראז'",
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'ראשון לציון',
#   'Price': '119000',
#   'Pic_num': 3,
#   'Cre_date': '22/08/2023',
#   'Repub_date': '22/08/2023',
#   'Description': 'מיצובישי אאוטלנדר 2018 , 7 מקומות דגם INSTYLE, יד פרטית ראשונה, ללא תאונות. קילומטראז נמוך 48,000. שמורה ומטופלת במוסך היבואן. 119,000 ש"ח. שי 0506776388',
#   'Color': 'לבן',
#   'Km': '48500',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2009',
#   'model': 'לנסר ספורטבק',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1800',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'פתח תקוה והסביבה',
#   'City': 'פתח תקווה',
#   'Price': '17000',
#   'Pic_num': 4,
#   'Cre_date': '09/07/2023',
#   'Repub_date': '09/07/2023',
#   'Description': 'הרכב אמין, שמור ומטופל, מצבר חדש ממש, מסך מולטימדיה גדול ואיכותי, מצלמת רוורס, מנוע 1800(!).',
#   'Color': 'שחור',
#   'Km': '183000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2005',
#   'model': 'לנסר קלאסיק',
#   'Hand': '3',
#   'Gear': 'טיפטרוניק',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'בית שמש והסביבה',
#   'City': 'בית שמש',
#   'Price': '7250',
#   'Pic_num': 7,
#   'Cre_date': '15/05/2023',
#   'Repub_date': '15/05/2023',
#   'Description': 'רכב שמור ללא תקלות יש טסט ל 7 חודש מזגן מקפיא יש לרכב שני מפתחות ושני שלטים בשווי כל אחד 300 שקלים מערכת שמע טובה מאוד עם בלוטוס מגיע עם שואב אבק שמתחבר למצת ש...',
#   'Color': 'כסוף',
#   'Km': '225000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2019',
#   'model': 'I-MIEV',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2400',
#   'Engine_type': 'היבריד',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'גדרה יבנה והסביבה',
#   'City': 'יבנה',
#   'Price': '141000',
#   'Pic_num': 1,
#   'Cre_date': '15/05/2023',
#   'Repub_date': '15/05/2023',
#   'Description': 'מיצובישי אאוטלנדר PHEV פלאג אין, שמורה ונקיה, טופלה במוסך היבואן, ק"מ נמוך, צמיגים חדשים',
#   'Color': 'כסוף מטאלי',
#   'Km': '64000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2012',
#   'model': 'לנסר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'חדרה וישובי עמק חפר',
#   'City': 'חדרה',
#   'Price': '15000',
#   'Pic_num': 1,
#   'Cre_date': '13/05/2023',
#   'Repub_date': '13/05/2023',
#   'Description': 'Mitsubishi Lancer Instyle 2012 1.6 יד 2 215,000 ק"מ טסט: 09 ברכב קיימת מערכת מולטימדיה Android 9.1 סאב חברת Pioneer ו2 אמפליפיירים מחברת Logic רכב מעולה לא עוש...',
#   'Color': 'לבן',
#   'Km': '215000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר קלאסיק',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ירושלים והסביבה',
#   'City': 'ירושלים',
#   'Price': '8000',
#   'Pic_num': 3,
#   'Cre_date': '25/03/2023',
#   'Repub_date': '25/03/2023',
#   'Description': 'לרכב הוחלף לאחרונה טיימינג משאבת מים בלמים קדימה תושבות גיר קדימה ואחורה שמנים ופילטרים',
#   'Color': 'אפור מטאלי',
#   'Km': '260000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2007',
#   'model': 'לנסר קלאסיק',
#   'Hand': '5',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ירושלים והסביבה',
#   'City': 'ירושלים',
#   'Price': '7700',
#   'Pic_num': 4,
#   'Cre_date': '25/03/2023',
#   'Repub_date': '25/03/2023',
#   'Description': 'רכב במצב מצוין הוחלף לאחרונה טיימינג משאבת מים שמנים ופילטרים בלמים אחורה וקדימה תושבות מנוע',
#   'Color': 'אפור מטאלי',
#   'Km': '194400',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2018',
#   'model': 'ספייס סטאר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1400',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ירושלים והסביבה',
#   'City': 'ירושלים',
#   'Price': '42500',
#   'Pic_num': 1,
#   'Cre_date': '17/02/2023',
#   'Repub_date': '17/02/2023',
#   'Description': 'NA',
#   'Color': 'כחול',
#   'Km': '95000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'I-MIEV',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'אחר',
#   'Curr_ownership': 'פרטית',
#   'Area': 'מודיעין והסביבה',
#   'City': 'מודיעין מכבים רעות',
#   'Price': '1',
#   'Pic_num': 4,
#   'Cre_date': '07/12/2022',
#   'Repub_date': '12/01/2023',
#   'Description': 'מיצובישי אאוטלנדר במצב טוב שמור ,לא עבר תאונות, טיפולים לפי הספר, מתחייב בבדיקה לרצינים בלבד פרטים בטלפון \u200e0542458443',
#   'Color': 'לבן מטאלי',
#   'Km': '206000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'נס ציונה - רחובות',
#   'City': 'רחובות',
#   'Price': '7500',
#   'Pic_num': 6,
#   'Cre_date': '27/12/2022',
#   'Repub_date': '27/12/2022',
#   'Description': 'Lancer 2008 יד3 טסט 3/23 200קמ מצב מכני מצויין+ נסיעה שקטה, הכל עובד מעולה הנחות לנהגים חדשים, חיילים ועולים חדשים‼️ Скидки новым репатриантам ‼️',
#   'Color': 'אפור מטאלי',
#   'Km': '200000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2018',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רמת גן - גבעתיים',
#   'City': 'גבעתיים',
#   'Price': '123000',
#   'Pic_num': 1,
#   'Cre_date': '29/10/2022',
#   'Repub_date': '29/10/2022',
#   'Description': 'מיצובישי ג\'יפ אאוטלנדר 7 מושבים נוסעים, שנת 2018 יד 2 לאחר טיפול במוסך מיצובישי. 74,000 ק"מ ללא תאונות. מערכת אנדרואיד מסך גדול, חלון בגג, ג\'אנטים מגנזיום, צמ...',
#   'Color': 'NA',
#   'Km': '74000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2019',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2360',
#   'Engine_type': 'חשמלי',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'גליל ועמקים',
#   'City': 'יוקנעם עילית',
#   'Price': '165000',
#   'Pic_num': 1,
#   'Cre_date': '27/10/2022',
#   'Repub_date': '27/10/2022',
#   'Description': 'דגם סופרים הכי מפואר פלאג אין phev',
#   'Color': 'NA',
#   'Km': '93000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2015',
#   'model': "אטראז'",
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'יישובי השומרון',
#   'City': 'עץ אפרים',
#   'Price': '26000',
#   'Pic_num': 1,
#   'Cre_date': '27/10/2022',
#   'Repub_date': '27/10/2022',
#   'Description': 'רכב במצב מעולה טסט לשנה. יד 1 ליסינג יד 2 פרטי מנכה. שמור מאד גלגלים חדשים מערכת מולטימדיה מצלמת דרך. &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מערכת מולטימדיה,...',
#   'Color': 'NA',
#   'Km': '213000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2021',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'טיפטרוניק',
#   'Engine_capacity': '2500',
#   'Engine_type': 'היברידי',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'מודיעין והסביבה',
#   'City': 'מודיעין מכבים רעות',
#   'Price': '207000',
#   'Pic_num': 1,
#   'Cre_date': '26/10/2022',
#   'Repub_date': '26/10/2022',
#   'Description': 'מצב מצויין שמור מאוד &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מערכת הגברה',
#   'Color': 'NA',
#   'Km': '25500',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר ספורטבק',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1800',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'עמק יזרעאל',
#   'City': 'גן נר',
#   'Price': '18000',
#   'Pic_num': 4,
#   'Cre_date': '24/10/2022',
#   'Repub_date': '24/10/2022',
#   'Description': 'דגם: לנסר ספורט החדשה מזגן מעולה תא מיטען ענק יושבת מצוין על הכביש מאוד אמינה ונוחה בטיחות מירבית (7 כריות אוויר).',
#   'Color': 'זהב מטאלי',
#   'Km': '300000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2014',
#   'model': 'אאוטלנדר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'קרית גת',
#   'Price': '65000',
#   'Pic_num': 1,
#   'Cre_date': '24/10/2022',
#   'Repub_date': '24/10/2022',
#   'Description': 'רכב מושלם ושמר מטופל בזמן במוסך מורשה מוכר כי קניתי אותו על חשמל יש בעיה בחלון ליד הנהג לכן אני קצת גמיש לעוד פרטים בפרטי &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt...',
#   'Color': 'NA',
#   'Km': '17777',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2019',
#   'model': "אטראז'",
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '80',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'אילת והערבה',
#   'City': 'אילת',
#   'Price': '60000',
#   'Pic_num': 1,
#   'Cre_date': '23/10/2022',
#   'Repub_date': '23/10/2022',
#   'Description': 'הרחב במצב טוב ללא תעונות במצב טוב שמור לחלוטין',
#   'Color': 'NA',
#   'Km': '115000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'נס ציונה - רחובות',
#   'City': 'נס ציונה',
#   'Price': '110000',
#   'Pic_num': 1,
#   'Cre_date': '23/10/2022',
#   'Repub_date': '23/10/2022',
#   'Description': 'יד ראשונה פרטית , מצב מצויין ללא תאונות',
#   'Color': 'NA',
#   'Km': '58000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2021',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1998',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'חולון - בת ים',
#   'City': 'חולון',
#   'Price': '165000',
#   'Pic_num': 1,
#   'Cre_date': '21/10/2022',
#   'Repub_date': '21/10/2022',
#   'Description': 'דגם הפרימיום היוקרתי. כולל ציפוי ננו קרמי, חימום במושבים, שבעה מושבים, גג נפתח, באחריות יצרן עד מרץ 2023,שמור ביותר, איתוראן אקטיב, מרימי שמשות וסוגר גג. מערכות...',
#   'Color': 'NA',
#   'Km': '30000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'NA',
#   'Year': '2019',
#   'model': 'NA',
#   'Hand': '1',
#   'Gear': 'טיפטרוניק',
#   'Engine_capacity': '2500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'חולון - בת ים',
#   'City': 'חולון',
#   'Price': 'NA',
#   'Pic_num': 1,
#   'Cre_date': '20/10/2022',
#   'Repub_date': '20/10/2022',
#   'Description': 'רכב שמור מטופל בחברה בזמן &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; וו גרירה',
#   'Color': 'NA',
#   'Km': '40000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'גבעת עדה',
#   'Price': '95000',
#   'Pic_num': 1,
#   'Cre_date': '19/10/2022',
#   'Repub_date': '19/10/2022',
#   'Description': 'רכב במצב מעולה, דגם Instyle, עבר את כל הטיפולים במוסך מיצובישי מורשה, 7 מושבים, כולל מובילאי, מערכת מולטימדיה מקורית, גג נפתח, בעלות קודמת ליסינג 0 ק"מ והיה ביד...',
#   'Color': 'NA',
#   'Km': '180000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'חיפה וחוף הכרמל',
#   'City': 'חיפה',
#   'Price': '100000',
#   'Pic_num': 1,
#   'Cre_date': '19/10/2022',
#   'Repub_date': '19/10/2022',
#   'Description': 'מיצובישי אאוטלנדר תאריך עלייה לכביש 10.08.2016... 163,000 קילומטר.... קיים תיק טיפולים + טסט לשנה ... 7 מקומות.',
#   'Color': 'NA',
#   'Km': '163000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'אקליפס',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1650',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'רמות מאיר',
#   'Price': '107000',
#   'Pic_num': 1,
#   'Cre_date': '19/10/2022',
#   'Repub_date': '19/10/2022',
#   'Description': 'רכב במצב מצויין',
#   'Color': 'NA',
#   'Km': '80000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2018',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'ראשון לציון',
#   'Price': '126000',
#   'Pic_num': 1,
#   'Cre_date': '18/10/2022',
#   'Repub_date': '18/10/2022',
#   'Description': 'אאוטלנדר אינסטנט כחדש דצמבר 2018 . נסע רק 9000 קמ . התחיבות למנוע גיר ושסי.',
#   'Color': 'NA',
#   'Km': '9000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2021',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1998',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'חיפה וחוף הכרמל',
#   'City': 'חיפה',
#   'Price': '159000',
#   'Pic_num': 1,
#   'Cre_date': '18/10/2022',
#   'Repub_date': '18/10/2022',
#   'Description': 'מכונית חדשה מרהיבה ועוצמתית באחריות החברה- עם כל התוספות המתבקשות.',
#   'Color': 'NA',
#   'Km': '34000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2010',
#   'model': 'לנסר הדור החדש',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'פרדס חנה - כרכור',
#   'City': 'פרדס חנה כרכור',
#   'Price': '12000',
#   'Pic_num': 1,
#   'Cre_date': '17/10/2022',
#   'Repub_date': '17/10/2022',
#   'Description': 'מצב מכני מעולה, טסט עד אוגוסט 2023, יד שניה',
#   'Color': 'NA',
#   'Km': '240000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2009',
#   'model': 'לנסר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'חיפה וחוף הכרמל',
#   'City': 'עתלית',
#   'Price': '14000',
#   'Pic_num': 5,
#   'Cre_date': '25/06/2022',
#   'Repub_date': '15/10/2022',
#   'Description': 'מיצובישי לנסר הדור החדש 2009 1500 סמ"ק בצבע כסף,טסט לשנה, אוטו במצב מעולה, אמין מאוד, מטופל תמיד בזמן עם חלפים מקוריים. אצלי 8 שנים שימש אותי נאמנה ללא תקלות. כ...',
#   'Color': 'כסוף מטאלי',
#   'Km': '199000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2013',
#   'model': 'אאוטלנדר',
#   'Hand': '4',
#   'Gear': 'טיפטרוניק',
#   'Engine_capacity': '255',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'אשדוד - אשקלון',
#   'City': 'אשקלון',
#   'Price': '65000',
#   'Pic_num': 1,
#   'Cre_date': '14/10/2022',
#   'Repub_date': '14/10/2022',
#   'Description': 'מיצובישי אאוטלנדר במצב מעולה הדגם המשופר Elite 4 על 4 ריפודי עור, חימום במושבים, מערכת אנדרואיד חדשה ברכב, וו גרירה, גגון כל התוספות של הדגם המפואר &lt;br/&g...',
#   'Color': 'NA',
#   'Km': '239',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2010',
#   'model': 'גרנדיס',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2400',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'בית שמש והסביבה',
#   'City': 'בית שמש',
#   'Price': '35000',
#   'Pic_num': 1,
#   'Cre_date': '13/10/2022',
#   'Repub_date': '13/10/2022',
#   'Description': 'רכב חזק אמין ונוח במיוחד. תא מטען ענק בקיפול המושבים הוא פשוט עצום. בגרסת הבסיס הרכב שותה דלק ולכן עבר הסבה לגז שנותנת נתונים של 1 ל15 כשעבור רכב בגודל הזה זה נ...',
#   'Color': 'NA',
#   'Km': '400000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'באר שבע',
#   'Price': '99000',
#   'Pic_num': 1,
#   'Cre_date': '07/10/2022',
#   'Repub_date': '07/10/2022',
#   'Description': 'למכירה מציאה של ממש** אאוטלנדר 2016 5 מקומות כמו חדש קילומטראז רק 39 אלף פרטית ..עם תוספות מדרכות צד ניקל איכותיות ומולטימדיה 10 כל האפליקציות פתוחות ..רכב חסכו...',
#   'Color': 'NA',
#   'Km': '41000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1800',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'יקנעם עילית',
#   'Price': '16900',
#   'Pic_num': 1,
#   'Cre_date': '07/10/2022',
#   'Repub_date': '07/10/2022',
#   'Description': 'מיצובישי לנסר 2008 רכב שמור מאוד טיפולים בזמן צבע די שמור נהגת יחידה מוכרת עקב מעבר לרכב חדש יותר הוחלף צמיגים, משולשים, תפוחים, הכל חדש רכב חזק מנוע 1800 יש את...',
#   'Color': 'NA',
#   'Km': '189',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'ספייס סטאר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רעננה - כפר סבא',
#   'City': 'כוכב יאיר',
#   'Price': '67000',
#   'Pic_num': 1,
#   'Cre_date': '06/10/2022',
#   'Repub_date': '06/10/2022',
#   'Description': 'טסט אוקטובר 2023! מצב מצוין, ק"מ נמוך, נהגת יחידה ניתן לראות בהרצליה/כוכב יאיר/תל אביב &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מצלמת רוורס car play',
#   'Color': 'NA',
#   'Km': '20000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2018',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רמת גן - גבעתיים',
#   'City': 'גבעתיים',
#   'Price': '131000',
#   'Pic_num': 1,
#   'Cre_date': '05/10/2022',
#   'Repub_date': '05/10/2022',
#   'Description': "ג'יפ מיצובישי אאוטלנדר 7 מקומות , אינסטייל , הנעה בכפתור ללא מפתח , חלון בגג , מערכת מולטימדיה אנדרואיד, טיפולים במוסך מיצובישי.",
#   'Color': 'NA',
#   'Km': '73000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2015',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'שדרות',
#   'Price': '94000',
#   'Pic_num': 1,
#   'Cre_date': '05/10/2022',
#   'Repub_date': '05/10/2022',
#   'Description': 'רכב שמור מטופל בזמן 2 נהגים בלבד עבר בדיקה לפני שבועיים טסט עד 12/22 &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מצלמת רוורס',
#   'Color': 'NA',
#   'Km': '109000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1998',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'פתח תקוה והסביבה',
#   'City': 'פתח תקווה',
#   'Price': '115000',
#   'Pic_num': 1,
#   'Cre_date': '04/10/2022',
#   'Repub_date': '04/10/2022',
#   'Description': 'מטופל בחברה',
#   'Color': 'NA',
#   'Km': '90000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'ספייס סטאר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'חברה',
#   'Curr_ownership': 'פרטית',
#   'Area': 'נתניה והסביבה',
#   'City': 'נתניה',
#   'Price': '70900',
#   'Pic_num': 4,
#   'Cre_date': '02/10/2022',
#   'Repub_date': '02/10/2022',
#   'Description': 'מציאה!! רכב שמור מאוד במצב מדהים נהגת יחידה עם מספר שלא תמצאו באף רכב שמור היטב מטופל רק בחברה.. לרצינים לפנות!! קילומטר נמוך!! 0504055111',
#   'Color': 'שחור',
#   'Km': '26800',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'ניר עציון',
#   'Price': '102000',
#   'Pic_num': 1,
#   'Cre_date': '28/09/2022',
#   'Repub_date': '28/09/2022',
#   'Description': 'רכב יד שניה, ללא תאונות, 7 מקומות, עשה טסט בחודש אוגוסט, צמיגים חדשים.',
#   'Color': 'NA',
#   'Km': '92000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2021',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'באר שבע',
#   'Price': '165000',
#   'Pic_num': 1,
#   'Cre_date': '26/09/2022',
#   'Repub_date': '26/09/2022',
#   'Description': 'רכב שמור מאוד',
#   'Color': 'NA',
#   'Km': '17000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2010',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1998',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'פתח תקוה והסביבה',
#   'City': 'פתח תקווה',
#   'Price': '42000',
#   'Pic_num': 1,
#   'Cre_date': '22/09/2022',
#   'Repub_date': '22/09/2022',
#   'Description': 'רכב שמור, צמיגים חדשים, מצבר חדש, טסט לשנה.',
#   'Color': 'NA',
#   'Km': '177000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '1990',
#   'model': 'לנסר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1468',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ראש העין והסביבה',
#   'City': 'אלעד',
#   'Price': '6000',
#   'Pic_num': 1,
#   'Cre_date': '21/09/2022',
#   'Repub_date': '21/09/2022',
#   'Description': 'אספנות נוסע מעולה טסט פעם בשנה ביטוח ממש זול מזגן מחבר חדש',
#   'Color': 'NA',
#   'Km': '240000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2022',
#   'model': 'ASX',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1998',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רמלה - לוד',
#   'City': 'לוד',
#   'Price': '150000',
#   'Pic_num': 1,
#   'Cre_date': '21/09/2022',
#   'Repub_date': '21/09/2022',
#   'Description': 'רכב חדש מהניילון חודש על הכביש קילומטר נמוך,תוספות גג חשמלי נפתח,חלונות חשמליים,מערכת מולטימדיה,חיישני קורס,משענת יד מושקעת. &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/...',
#   'Color': 'NA',
#   'Km': '300',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1584',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'אשדוד - אשקלון',
#   'City': 'אשקלון',
#   'Price': '12000',
#   'Pic_num': 1,
#   'Cre_date': '19/09/2022',
#   'Repub_date': '19/09/2022',
#   'Description': "רכב במצב טוב. נהג הרכב יחיד. טסט מסתיים בעוד חודש. קילומרז' נמוך. יד ראשונה -ליסינג.",
#   'Color': 'NA',
#   'Km': '153678',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'ASX',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'באר שבע',
#   'Price': '123000',
#   'Pic_num': 1,
#   'Cre_date': '16/09/2022',
#   'Repub_date': '16/09/2022',
#   'Description': 'דגם פרימיום , חימום מושבים , גג פנורמי , מסך מולטימדיה, מושבי עור',
#   'Color': 'NA',
#   'Km': '28000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'אשדוד - אשקלון',
#   'City': 'אשדוד',
#   'Price': '109500',
#   'Pic_num': 1,
#   'Cre_date': '16/09/2022',
#   'Repub_date': '16/09/2022',
#   'Description': 'יד 02 ליסינג תפעולי נהג יחיד לשעבר מנוע 1.99 בנזין 150 כס גימור אינסטייל צבע כסף 128,585 קמ 7 מקומות תוספות: וו גרירה, חיבור חשמל, מערכת Mobil Eye ...',
#   'Color': 'NA',
#   'Km': '128585',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2021',
#   'model': 'ASX',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'חדרה וישובי עמק חפר',
#   'City': 'חדרה',
#   'Price': '135000',
#   'Pic_num': 1,
#   'Cre_date': '16/09/2022',
#   'Repub_date': '16/09/2022',
#   'Description': 'מיצובישי מסוג asx מודל 2021, יד ראשונה מפרטי , לפרטיי יש ליצור קשר 0522661185 &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מצלמה , איתורן, מגיני צד',
#   'Color': 'NA',
#   'Km': '10000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'אשדוד - אשקלון',
#   'City': 'אשדוד',
#   'Price': '110000',
#   'Pic_num': 1,
#   'Cre_date': '14/09/2022',
#   'Repub_date': '14/09/2022',
#   'Description': 'ב"ה 7 מקומות שמור מאוד לאחר טיפול גדול במיציבושי טסט לשנה. +גגון. ריפודים במצב חדש.',
#   'Color': 'NA',
#   'Km': '115000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1300',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'טבריה והסביבה',
#   'City': 'טבריה',
#   'Price': '6000',
#   'Pic_num': 1,
#   'Cre_date': '13/09/2022',
#   'Repub_date': '13/09/2022',
#   'Description': 'מיציבושי לנסר במצב מצוין טסט לשנה',
#   'Color': 'NA',
#   'Km': 'NA',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'נחושה',
#   'Price': '87000',
#   'Pic_num': 1,
#   'Cre_date': '12/09/2022',
#   'Repub_date': '12/09/2022',
#   'Description': 'רכב פשוט מעולה! נאלצים להיפרד כיוון שכבר לא זקוקים ל7 מקומות ולכן עוברים למשפחתי. אתם תהנו ממנו!',
#   'Color': 'NA',
#   'Km': '129560',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'NA',
#   'Year': '2016',
#   'model': 'NA',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'שעב',
#   'Price': 'NA',
#   'Pic_num': 1,
#   'Cre_date': '11/09/2022',
#   'Repub_date': '11/09/2022',
#   'Description': 'NA',
#   'Color': 'NA',
#   'Km': '150',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'NA',
#   'Year': '2016',
#   'model': 'NA',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'שעב',
#   'Price': 'NA',
#   'Pic_num': 1,
#   'Cre_date': '11/09/2022',
#   'Repub_date': '11/09/2022',
#   'Description': "מיצופישי אווט לנדר 2016 150 ק'ש 7 מושבים גג",
#   'Color': 'NA',
#   'Km': '150',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רעננה - כפר סבא',
#   'City': 'כפר סבא',
#   'Price': '105000',
#   'Pic_num': 1,
#   'Cre_date': '10/09/2022',
#   'Repub_date': '10/09/2022',
#   'Description': 'רכב עם נהג יחיד בכל התקופה, ללא תאונות למעט שריטות. טסט עד יוני 2023',
#   'Color': 'NA',
#   'Km': '123500',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2009',
#   'model': 'לנסר הדור החדש',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'הוד השרון והסביבה',
#   'City': 'הוד השרון',
#   'Price': '15000',
#   'Pic_num': 1,
#   'Cre_date': '10/09/2022',
#   'Repub_date': '10/09/2022',
#   'Description': "רכב יד ראשונה, קילומטרג' נמוך. גמיש במחיר.",
#   'Color': 'NA',
#   'Km': '130000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'אקליפס',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'פתח תקוה והסביבה',
#   'City': 'פתח תקווה',
#   'Price': '132000',
#   'Pic_num': 1,
#   'Cre_date': '07/09/2022',
#   'Repub_date': '07/09/2022',
#   'Description': 'רכב חדש לחלוטין, שמור מאוד, קילומטרז אפסי, nbug 1500 yurcu\' מטופל במוסף נירון מוטורס פ"ת. עבר טסט וטיפול כעת כך שיש עוד שנה לטסט ולטיפול הבא, מערכות סטיית נתיב ...',
#   'Color': 'NA',
#   'Km': '15500',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'חיפה וחוף הכרמל',
#   'City': 'חיפה',
#   'Price': '110000',
#   'Pic_num': 1,
#   'Cre_date': '06/09/2022',
#   'Repub_date': '06/09/2022',
#   'Description': 'טסט לשנה , צמיגים חדשים , מערכת שמע מקורית מעולה, חניה בחניון מקורה',
#   'Color': 'NA',
#   'Km': '36000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'אקליפס',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'ראשון לציון',
#   'Price': '131000',
#   'Pic_num': 1,
#   'Cre_date': '06/09/2022',
#   'Repub_date': '06/09/2022',
#   'Description': 'יד ראשונה פרטית, רכב חדש לגמרי,שמור ומטופל,ללא תאונות, אחריות יצרן מלאה על הרכב,מערכת מולטימדייה, גג נפתח כפול נהג יחיד, ללא תאונות. לרציניים בלבד. &lt;br/&g...',
#   'Color': 'NA',
#   'Km': '56000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר קלאסיק',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'טבריה והסביבה',
#   'City': 'קצרין',
#   'Price': '8000',
#   'Pic_num': 1,
#   'Cre_date': '04/09/2022',
#   'Repub_date': '04/09/2022',
#   'Description': 'רכב פצצה לאחר טיימינג משאבת מים ועוד…',
#   'Color': 'NA',
#   'Km': '240',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2018',
#   'model': 'אקליפס',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1400',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'ראשון',
#   'Price': '120000',
#   'Pic_num': 1,
#   'Cre_date': '04/09/2022',
#   'Repub_date': '04/09/2022',
#   'Description': 'דגם מפואר גג פנורמי ריפודים מעור רכב שמור',
#   'Color': 'NA',
#   'Km': '63358',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'מעלה עירון',
#   'Price': '93000',
#   'Pic_num': 1,
#   'Cre_date': '04/09/2022',
#   'Repub_date': '04/09/2022',
#   'Description': 'רכב שמור במצב טוב . לסינג לשעבר',
#   'Color': 'NA',
#   'Km': '118000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'באר שבע',
#   'Price': '105000',
#   'Pic_num': 1,
#   'Cre_date': '03/09/2022',
#   'Repub_date': '03/09/2022',
#   'Description': 'למכירה מציאה של ממש** אאוטלנדר 2016 דגם אינטנס 5 מקומות כמו חדש קילומטראז רק 39 אלף פרטית ..עם תוספות מדרכות צד ניקל איכותיות ומולטימדיה 10 כל האפליקציות פתוחות...',
#   'Color': 'NA',
#   'Km': 'NA',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'אילת והערבה',
#   'City': 'אילת',
#   'Price': '100000',
#   'Pic_num': 1,
#   'Cre_date': '03/09/2022',
#   'Repub_date': '03/09/2022',
#   'Description': 'מצב טוב מאוד. נהג יחיד. כל טיפולים בזמן. ללא תאונות.',
#   'Color': 'NA',
#   'Km': '85000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2019',
#   'model': 'ASX',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'פתח תקוה והסביבה',
#   'City': 'פתח תקווה',
#   'Price': '95000',
#   'Pic_num': 1,
#   'Cre_date': '31/08/2022',
#   'Repub_date': '31/08/2022',
#   'Description': 'רכב שמור נהג יחיד כולל מערכת מולטי מדיה מקורית. קילומטרז נמוך. מטופל במיצובישי',
#   'Color': 'NA',
#   'Km': '40000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2010',
#   'model': 'גרנדיס',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2400',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'נתיבות',
#   'Price': '18000',
#   'Pic_num': 1,
#   'Cre_date': '29/08/2022',
#   'Repub_date': '29/08/2022',
#   'Description': 'דרושה רק החלפת מנוע והמחיר בהתאם הרכב עם מערכת גז לאחר טיפול גדול',
#   'Color': 'NA',
#   'Km': '360000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'ראשון לציון',
#   'Price': '110000',
#   'Pic_num': 1,
#   'Cre_date': '29/08/2022',
#   'Repub_date': '29/08/2022',
#   'Description': 'רכב שמור מאד, מטופל במוסך היבואן, ללא תאונות,נהג יחיד,5 מקומות',
#   'Color': 'NA',
#   'Km': '153000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2018',
#   'model': 'ASX',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רמת גן - גבעתיים',
#   'City': 'רמת גן',
#   'Price': '80000',
#   'Pic_num': 1,
#   'Cre_date': '29/08/2022',
#   'Repub_date': '29/08/2022',
#   'Description': 'רכב במצב מצוין, לאחר טיפול גדול והחלפת צמיגים (מישלין 4 גלגלים) לרציניים בלבד .',
#   'Color': 'NA',
#   'Km': '71000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'ספייס סטאר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'NA',
#   'City': 'מתתיהו',
#   'Price': '38500',
#   'Pic_num': 3,
#   'Cre_date': '28/08/2022',
#   'Repub_date': '28/08/2022',
#   'Description': 'אמין וחסכוני.... והמחיר הוא סופי....',
#   'Color': 'כסוף',
#   'Km': '57000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2011',
#   'model': 'גרנדיס',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2400',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'באקה אל-גרביה',
#   'Price': '40000',
#   'Pic_num': 1,
#   'Cre_date': '23/08/2022',
#   'Repub_date': '23/08/2022',
#   'Description': 'NA',
#   'Color': 'NA',
#   'Km': '147000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2011',
#   'model': 'גרנדיס',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2400',
# ...
#   'Color': 'NA',
#   'Km': 'NA',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2019',
#   'model': 'אקליפס',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1499',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רמת גן - גבעתיים',
#   'City': 'רמת גן',
#   'Price': '124000',
#   'Pic_num': 1,
#   'Cre_date': '09/05/2022',
#   'Repub_date': '09/05/2022',
#   'Description': 'רכב שני. ק"מ נמוך מטופל אצל היבואן. יימכר לאחר טיפול גדול. שווה! &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; דגם INTENSE',
#   'Color': 'NA',
#   'Km': '32900',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2021',
#   'model': 'אקליפס',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1499',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'Ashdod',
#   'Price': '145000',
#   'Pic_num': 1,
#   'Cre_date': '01/05/2022',
#   'Repub_date': '01/05/2022',
#   'Description': 'מיצובישי אקליפס דגם INSTY הרכב מטופל במוסך מורשה מיצובישי אשדוד לרכב יש טסט עד 01/23 &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מראות חשמליות, גאנטים, גג נפתח, מ...',
#   'Color': 'NA',
#   'Km': '21563',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'NA',
#   'Year': '2022',
#   'model': 'NA',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1226',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'חולון - בת ים',
#   'City': 'בת ים',
#   'Price': 'NA',
#   'Pic_num': 1,
#   'Cre_date': '27/04/2022',
#   'Repub_date': '27/04/2022',
#   'Description': 'רכב חדש מה ניילונים',
#   'Color': 'NA',
#   'Km': '1500',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2015',
#   'model': 'ספייס סטאר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'ראשון לציון',
#   'Price': '36900',
#   'Pic_num': 1,
#   'Cre_date': '18/04/2022',
#   'Repub_date': '18/04/2022',
#   'Description': 'לבוא לקחת. התחייבות לקנייה חוזרת עד 5 שנים. שקיפות מלאה!!! מגוון אפשרויות מימון עד 100% כולל תשלום בצקים. נמצא בסוכנות "גרינקאר" בראשל"צ, רח\' הרצל 28. הנחות ומח...',
#   'Color': 'NA',
#   'Km': 'NA',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2010',
#   'model': 'לנסר',
#   'Hand': '4',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'באר שבע והסביבה',
#   'City': 'אופקים',
#   'Price': '17000',
#   'Pic_num': 7,
#   'Cre_date': '17/11/2021',
#   'Repub_date': '17/11/2021',
#   'Description': 'מיצבושי לנסר החדשה',
#   'Color': 'אפור',
#   'Km': '200000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר קלאסיק',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'טבריה והסביבה',
#   'City': 'טבריה',
#   'Price': '6000',
#   'Pic_num': 10,
#   'Cre_date': '15/10/2021',
#   'Repub_date': '15/10/2021',
#   'Description': 'מיצובישי לאנסר 2008 אוטמט 98 כ״ס יד 03 230 אלף ק״מ במצב מכאני מעולה במערכת מותקנת דיברוית ובלוטוס לשירים בס ורמקולים של פיוניר חלונות מושחרים אחוריים רכ...',
#   'Color': 'אפור עכבר',
#   'Km': '230000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'סופר לנסר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1800',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'רמת גן - גבעתיים',
#   'City': 'בני ברק',
#   'Price': '16500',
#   'Pic_num': 4,
#   'Cre_date': '04/10/2021',
#   'Repub_date': '04/10/2021',
#   'Description': "רכב רחב ומפנק, קילומטרז' נמוך לגילו, ללא תאונות, מטופל בזמן.",
#   'Color': "בז'",
#   'Km': '176000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2005',
#   'model': 'לנסר קלאסיק',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1800',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'ירושלים והסביבה',
#   'City': 'ירושלים',
#   'Price': '4500',
#   'Pic_num': 0,
#   'Cre_date': '29/09/2023',
#   'Repub_date': '29/09/2023',
#   'Description': "רכב תקין ללא שום בעיות. מזגן מקפיא! הושקע מולטימדיה יותר מ1000 שח טסט לעוד חצי שנה . מוכר בכ''כ זול משום שאני כבר לא משתמש עם הרכב",
#   'Color': 'כסוף',
#   'Km': '323000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2014',
#   'model': "אטראז'",
#   'Hand': '4',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'ראשון לציון',
#   'Price': '26000',
#   'Pic_num': 0,
#   'Cre_date': '29/10/2022',
#   'Repub_date': '29/10/2022',
#   'Description': 'רכב שמור מטופל בזמן ניראה כמו חדש מפתח חכם גמיש במחיר',
#   'Color': 'NA',
#   'Km': '160000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2008',
#   'model': 'לנסר',
#   'Hand': '5',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1584',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רמת גן - גבעתיים',
#   'City': 'בני ברק',
#   'Price': '13000',
#   'Pic_num': 0,
#   'Cre_date': '25/10/2022',
#   'Repub_date': '25/10/2022',
#   'Description': 'NA',
#   'Color': 'NA',
#   'Km': '152600',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2012',
#   'model': 'לנסר הדור החדש',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ירושלים והסביבה',
#   'City': 'ירושלים',
#   'Price': '25500',
#   'Pic_num': 0,
#   'Cre_date': '15/10/2022',
#   'Repub_date': '15/10/2022',
#   'Description': 'רכב שמור ומטופל טסט לשנה',
#   'Color': 'NA',
#   'Km': '130000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2010',
#   'model': 'לנסר הדור החדש',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'נתיבות',
#   'Price': '14500',
#   'Pic_num': 0,
#   'Cre_date': '14/10/2022',
#   'Repub_date': '14/10/2022',
#   'Description': 'NA',
#   'Color': 'NA',
#   'Km': '295000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2009',
#   'model': 'I-MIEV',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '3200',
#   'Engine_type': 'דיזל',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'חולון - בת ים',
#   'City': 'בת ים',
#   'Price': '95000',
#   'Pic_num': 2,
#   'Cre_date': '15/05/2022',
#   'Repub_date': '15/05/2022',
#   'Description': 'הכול מקורי פנים וחוץ האותו 4X4 נפח 3200',
#   'Color': 'לבן',
#   'Km': '100000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'אשדוד - אשקלון',
#   'City': 'אשדוד',
#   'Price': '106500',
#   'Pic_num': 0,
#   'Cre_date': '27/09/2022',
#   'Repub_date': '27/09/2022',
#   'Description': 'מיצובישי אאוטלנדר 08/2016 יד 02 ליסינג תפעולי נהג יחיד לשעבר מנוע 1.99 בנזין 150 כס גימור אינסטייל: חלון בגג, מפתח חכם ועוד צבע כסף 7 מקומות תוספות: ...',
#   'Color': 'NA',
#   'Km': '128585',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2021',
#   'model': 'ספייס סטאר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'נתניה והסביבה',
#   'City': 'נתניה',
#   'Price': '76000',
#   'Pic_num': 0,
#   'Cre_date': '27/09/2022',
#   'Repub_date': '27/09/2022',
#   'Description': 'רכב חדש של אדם מבוגר (אבא שלי) רק 6000 ק"מ, ללא שריטה , חונה תמיד בחניון מקורה מתחת לבניין נמכר עקב חוסר שימוש',
#   'Color': 'NA',
#   'Km': '6000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2007',
#   'model': 'לנסר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'רעננה - כפר סבא',
#   'City': 'כפר סבא',
#   'Price': '3500',
#   'Pic_num': 0,
#   'Cre_date': '17/09/2022',
#   'Repub_date': '17/09/2022',
#   'Description': 'NA',
#   'Color': 'NA',
#   'Km': '318000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2015',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'מודיעין והסביבה',
#   'City': 'מודיעין מכבים רעות',
#   'Price': '70000',
#   'Pic_num': 0,
#   'Cre_date': '02/09/2022',
#   'Repub_date': '02/09/2022',
#   'Description': 'NA',
#   'Color': 'NA',
#   'Km': '185000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2016',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'נתניה והסביבה',
#   'City': 'נתניה',
#   'Price': '990000',
#   'Pic_num': 0,
#   'Cre_date': '01/09/2022',
#   'Repub_date': '01/09/2022',
#   'Description': 'מיצובישי אאוטלנדר 7 מקומות מצב חדש אוטו שמור שמור',
#   'Color': 'NA',
#   'Km': '122000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2007',
#   'model': 'לנסר קלאסיק',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'תל אבי',
#   'Price': '10000',
#   'Pic_num': 0,
#   'Cre_date': '27/08/2022',
#   'Repub_date': '27/08/2022',
#   'Description': 'NA',
#   'Color': 'NA',
#   'Km': '86000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2022',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'עמק יזרעאל',
#   'City': 'קרית טבעון',
#   'Price': '240000',
#   'Pic_num': 0,
#   'Cre_date': '30/07/2022',
#   'Repub_date': '30/07/2022',
#   'Description': 'אאוטלנדר החדש דגם פרימיום 2022 יד ראשונה רכב חדש חדש עשה רק 6000 &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; ריפודי עור סנטטי רכב מבוקש מאוד ושמור כל הקודם זוכה...',
#   'Color': 'NA',
#   'Km': '6000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2021',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'קריות',
#   'City': 'קרית ביאליק',
#   'Price': '210000',
#   'Pic_num': 0,
#   'Cre_date': '23/07/2022',
#   'Repub_date': '23/07/2022',
#   'Description': 'NA',
#   'Color': 'NA',
#   'Km': '15000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2019',
#   'model': 'אקליפס',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'תל אביב',
#   'City': 'תל אביב יפו',
#   'Price': '150000',
#   'Pic_num': 0,
#   'Cre_date': '18/07/2022',
#   'Repub_date': '18/07/2022',
#   'Description': 'גג נפתח גם מאחורה',
#   'Color': 'NA',
#   'Km': '10000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2018',
#   'model': 'ASX',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ראשל"צ והסביבה',
#   'City': 'בית דגן',
#   'Price': '90000',
#   'Pic_num': 0,
#   'Cre_date': '15/07/2022',
#   'Repub_date': '15/07/2022',
#   'Description': 'רכב שמור מטופל במוסכי מיטצובישי בלבד. לא עבור תאונות.יד פרטית.',
#   'Color': 'NA',
#   'Km': '102000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2019',
#   'model': 'ASX',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'NA',
#   'City': 'יקנעם עילית',
#   'Price': '107000',
#   'Pic_num': 0,
#   'Cre_date': '14/07/2022',
#   'Repub_date': '14/07/2022',
#   'Description': 'שמורה מאד,מטופלת אך ורק במוסך מורשה ללא תאונות',
#   'Color': 'NA',
#   'Km': '69000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2007',
#   'model': 'לנסר',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1600',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'ירושלים והסביבה',
#   'City': 'ירושלים',
#   'Price': '6000',
#   'Pic_num': 0,
#   'Cre_date': '27/06/2022',
#   'Repub_date': '27/06/2022',
#   'Description': 'רכב מצוין,חסכוני,טסט בעוד חודש,מזגן מעולה,ישנם קילופי צבע, יד ראשונה היתה השכרה לא בשבת! &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; קודנית,בלוטוס,חיישני רוורס,גל...',
#   'Color': 'NA',
#   'Km': '162000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'אאוטלנדר',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1998',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'מודיעין והסביבה',
#   'City': 'מודיעין מכבים רעות',
#   'Price': '106000',
#   'Pic_num': 0,
#   'Cre_date': '22/05/2022',
#   'Repub_date': '22/05/2022',
#   'Description': 'מצב מצויין, שמור, כל הטיפולים בסוכנות מיצובישי/יונדאי מודיעין מתועדים. צמיגים חדשים, מצבר שנה וחצי. חלונות חשמלים, נעילה /פתיחה מרכזית מהשלט, מראות חשמליים.',
#   'Color': 'NA',
#   'Km': '122000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2020',
#   'model': 'אקליפס',
#   'Hand': '1',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'מודיעין והסביבה',
#   'City': 'מודיעין',
#   'Price': '129000',
#   'Pic_num': 0,
#   'Cre_date': '11/05/2022',
#   'Repub_date': '11/05/2022',
#   'Description': 'רכב שמור נמצא בחניה מקורה נהג יחיד(70)',
#   'Color': 'NA',
#   'Km': '16000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2010',
#   'model': 'לנסר הדור החדש',
#   'Hand': '3',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1500',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'קריות',
#   'City': 'רכסים',
#   'Price': '11500',
#   'Pic_num': 0,
#   'Cre_date': '05/05/2022',
#   'Repub_date': '05/05/2022',
#   'Description': 'חלונות שחורים מסך באגז גדול מושבים יפים',
#   'Color': 'NA',
#   'Km': '220000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2017',
#   'model': 'אאוטלנדר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '2000',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'NA',
#   'Curr_ownership': 'NA',
#   'Area': 'באר שבע והסביבה',
#   'City': 'באר שבע',
#   'Price': '115000',
#   'Pic_num': 0,
#   'Cre_date': '26/04/2022',
#   'Repub_date': '26/04/2022',
#   'Description': 'הרכב במצב מצויין טסט שלמה שלמה צלחות ברקסים וצמיגים חדשים טיפולצרק במוסך מורשה מלא תוספות זה דגם אינסטייל עם חלון בגג והנעה ללא מתפתח מראות מתקפלות ו...',
#   'Color': 'NA',
#   'Km': '85000',
#   'Test': 'NA',
#   'Supply_score': 'NA'},
#  {'manufactor': 'מיצובישי',
#   'Year': '2015',
#   'model': 'ספייס סטאר',
#   'Hand': '2',
#   'Gear': 'אוטומטית',
#   'Engine_capacity': '1200',
#   'Engine_type': 'בנזין',
#   'Prev_ownership': 'פרטית',
#   'Curr_ownership': 'פרטית',
#   'Area': 'בית שמש והסביבה',
#   'City': 'בית שמש',
#   'Price': '36000',
#   'Pic_num': 0,
#   'Cre_date': '13/01/2022',
#   'Repub_date': '13/01/2022',
#   'Description': 'נהגת יחידה. אוטו שני בבית.הרכב במצב חדשש. 4צמיגים חדשים .מצבר חדש .לאחר טיפול 100 אלף .חונה בחניה מקורה חסכוני מאוד שמור ומטופל ברמות כול הקודם זוכה',
#   'Color': 'כסוף מטאלי',
#   'Km': '100',
#   'Test': 'NA',
#   'Supply_score': 'NA'}]

# %%
import pandas as pd

# %%
scrape_df = pd.DataFrame(mitsu)

# %%
scrape_df
# Out:
#     manufactor  Year           model Hand      Gear Engine_capacity  \
# 0     מיצובישי  2005     לנסר קלאסיק    8  אוטומטית            1600
# 1     מיצובישי  2016          GT3000    2  אוטומטית            2000
# 2     מיצובישי  2016          I-MIEV    2  אוטומטית            2000
# 3     מיצובישי  2020          אקליפס    2  אוטומטית            2000
# 4     מיצובישי  2010            לנסר    3  אוטומטית            1600
# ..         ...   ...             ...  ...       ...             ...
# 154   מיצובישי  2017        אאוטלנדר    1  אוטומטית            1998
# 155   מיצובישי  2020          אקליפס    1  אוטומטית            1500
# 156   מיצובישי  2010  לנסר הדור החדש    3  אוטומטית            1500
# 157   מיצובישי  2017        אאוטלנדר    2  אוטומטית            2000
# 158   מיצובישי  2015      ספייס סטאר    2  אוטומטית            1200
#
#     Engine_type Prev_ownership Curr_ownership             Area  \
# 0         בנזין          פרטית          פרטית  ירושלים והסביבה
# 1         בנזין          פרטית          פרטית  חיפה וחוף הכרמל
# 2         בנזין          פרטית          פרטית  חיפה וחוף הכרמל
# 3         בנזין         ליסינג          פרטית  חיפה וחוף הכרמל
# 4         בנזין          פרטית          פרטית    נתניה והסביבה
# ..          ...            ...            ...              ...
# 154       בנזין             NA             NA  מודיעין והסביבה
# 155       בנזין             NA             NA  מודיעין והסביבה
# 156       בנזין             NA             NA            קריות
# 157       בנזין             NA             NA  באר שבע והסביבה
# 158       בנזין          פרטית          פרטית  בית שמש והסביבה
#
#                    City   Price  Pic_num    Cre_date  Repub_date  \
# 0               ירושלים    4700        3  22/05/2024  27/05/2024
# 1                   נשר   92000        4  05/05/2024  05/05/2024
# 2                   נשר   92000        4  05/05/2024  04/05/2024
# 3             טירת כרמל   85000        3  25/04/2024  25/04/2024
# 4                 נתניה   10000        7  16/03/2024  16/03/2024
# ..                  ...     ...      ...         ...         ...
# 154  מודיעין מכבים רעות  106000        0  22/05/2022  22/05/2022
# 155             מודיעין  129000        0  11/05/2022  11/05/2022
# 156               רכסים   11500        0  05/05/2022  05/05/2022
# 157             באר שבע  115000        0  26/04/2022  26/04/2022
# 158             בית שמש   36000        0  13/01/2022  13/01/2022
#
#                                            Description       Color      Km  \
# 0    רכב במצב פצצה שירת אותי נאמנה הוחלף לפני חודש ...        כסוף  230000
# 1    אאוטלנדר המפואר פרמיום 7 מקומות טופל אצל היבוא...         לבן  141000
# 2    אאוטלנדר הדגם המפואר 7 מקומות שמור ומטופל אצל ...         לבן  141000
# 3              מיצובישי ASX 76,000 ק"מ מוכן גם להחליף.        שחור   76000
# 4    גיר מנוע תקינים מעככת מוביליין רכב 7 שנים עצלי...        כסוף  242000
# ..                                                 ...         ...     ...
# 154  מצב מצויין, שמור, כל הטיפולים בסוכנות מיצובישי...          NA  122000
# 155             רכב שמור נמצא בחניה מקורה נהג יחיד(70)          NA   16000
# 156            חלונות שחורים מסך באגז גדול מושבים יפים          NA  220000
# 157  הרכב במצב מצויין טסט שלמה שלמה צלחות ברקסים וצ...          NA   85000
# 158  נהגת יחידה. אוטו שני בבית.הרכב במצב חדשש. 4צמי...  כסוף מטאלי     100
#
#     Test Supply_score
# 0    141           NA
# 1     NA           NA
# 2    261           NA
# 3    110           NA
# 4    171           NA
# ..   ...          ...
# 154   NA           NA
# 155   NA           NA
# 156   NA           NA
# 157   NA           NA
# 158   NA           NA
#
# [159 rows x 20 columns]

# %%
int_lst = ['Year','Hand','Engine_capacity','Pic_num','Km','Test']
str_lst = ['manufactor','model','Area','City','Description','Color']
date_lst = ['Cre_date','Repub_date']
cat_lst = ['Gear','Engine_type','Prev_ownership','Curr_ownership']

# %%
# Convert 
scrape_df[int_lst] = scrape_df[int_lst].apply(pd.to_numeric,errors='coerce').astype('Int64')
scrape_df["Price"] = scrape_df["Price"].apply(pd.to_numeric,errors='coerce').astype(float)
scrape_df[date_lst] = scrape_df[date_lst].apply(lambda x : pd.to_datetime(x,format='%d/%m/%Y'))
scrape_df[str_lst] = scrape_df[str_lst].astype(str)
scrape_df[cat_lst] = scrape_df[cat_lst].astype('category')

# %%
scrape_df.dtypes
# Out:
# manufactor                 object
# Year                        Int64
# model                      object
# Hand                        Int64
# Gear                     category
# Engine_capacity             Int64
# Engine_type              category
# Prev_ownership           category
# Curr_ownership           category
# Area                       object
# City                       object
# Price                     float64
# Pic_num                     Int64
# Cre_date           datetime64[ns]
# Repub_date         datetime64[ns]
# Description                object
# Color                      object
# Km                          Int64
# Test                        Int64
# Supply_score                Int64
# dtype: object

# %%
###### מתחת לזה אני שם את הקוד של הapi

# %%
import urllib.request
import urllib.parse
import json

# %%
def fetch_filtered_data_from_api(api_url, resource_id, query, keys_to_extract, limit=1000):
    offset = 0
    all_records = []

    while True:
        # Construct the URL with limit, offset, and query parameters
        params = {
            'resource_id': resource_id,
            'limit': limit,
            'offset': offset,
            'q': query
        }
        url = f"{api_url}?{urllib.parse.urlencode(params)}"
        
        print(f"Fetching URL: {url}")  # Debugging statement to see the full URL

        # Make a GET request to the API
        with urllib.request.urlopen(url) as response:
            if response.status == 200:
                data = json.loads(response.read().decode())
                
                # Check if the response contains the 'result' key
                if 'result' in data:
                    records = data['result']['records']
                    
                    if not records:
                        print("No records found.")
                        break
                    
                    # Filter the records to include only the specified keys
                    filtered_records = [
                        {key: record.get(key, 'NA') for key in keys_to_extract}
                        for record in records
                    ]
                    
                    # Add the filtered records to the all_records list
                    all_records.extend(filtered_records)
                    
                    # Update the offset for the next iteration
                    offset += limit
                else:
                    print("No 'result' key found in the API response.")
                    break
            else:
                print(f"Failed to fetch data from API. Status code: {response.status}")
                break

    return all_records
# Base URL for the API
api_url = 'https://data.gov.il/api/3/action/datastore_search'
    
# Resource ID for the dataset
resource_id = '5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6'
    
# Query parameter for Mitsubishi vehicles
query = 'מיצובישי'
    
# Keys to extract from the API response
keys_to_extract = ['tozar', 'kinuy_mishari', 'shnat_yitzur']
    
# Fetch filtered data from the API
filtered_data = fetch_filtered_data_from_api(api_url, resource_id, query, keys_to_extract)
# Out:
# Fetching URL: https://data.gov.il/api/3/action/datastore_search?resource_id=5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6&limit=1000&offset=0&q=%D7%9E%D7%99%D7%A6%D7%95%D7%91%D7%99%D7%A9%D7%99
# Fetching URL: https://data.gov.il/api/3/action/datastore_search?resource_id=5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6&limit=1000&offset=1000&q=%D7%9E%D7%99%D7%A6%D7%95%D7%91%D7%99%D7%A9%D7%99
# Fetching URL: https://data.gov.il/api/3/action/datastore_search?resource_id=5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6&limit=1000&offset=2000&q=%D7%9E%D7%99%D7%A6%D7%95%D7%91%D7%99%D7%A9%D7%99
# No records found.

# %%
filtered_data
# Out:
# [{'tozar': 'מיצובישי',
#   'kinuy_mishari': 'מיצובישי סופר לנסר I',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'מיצובישי סופר לנסר I',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'מיצובישי סופר לנסר I',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'מיצובישי סופר לנסר I',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': '004-L מיניבוס בנזין',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L-200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט SLG 0002',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': '004-L קומבי דיזל ידנ',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'קומבי 004L', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה 6.1 RATS 4 דל',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'קומבי דיזל 2+3',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CARISMA', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה 6.1 RATS 4 דל',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'מיניבוס 004L', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'MONTERO SPORT', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUILANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'טנדר 002-L SLG דגם ג',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L300', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': "כריזמה 6.1 XLG 4דלת'",
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'מיניבוס 004L', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'כריזמה 4דל LG', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'מגנום תא כפול', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'מיניבוס 004L', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'סופר לנסר ILG סלון',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט SLG 0081',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CARISMA', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L300', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L-200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CARISMA', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'טנדר 002-L SLG דגם ב',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': "כריזמה 6.1RATS 4דלת'",
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': "כריזמה 6.1 XLG 4דלת'",
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט ISLG 0081',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'קומבי דיזל 2+6',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'פגרו ארוך בנזין אוטו',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'קומבי דיזל 2+6 אוטוב',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט SLG 0081',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'קומבי דיזל 1+3',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUILANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'סופר לנסר ILG סלון',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה 9.1XLG דיזל 1',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'טנדר 002-L SLG דגם א',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2009},
# ...
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'מיניבוס 004L', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'ECLIPS CROSS PH',
#   'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L300', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'פגרו קצר בנזין אוטומ',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'ספייס ראנר 4X4 ידני',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'ECLIPS CROSS PH',
#   'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L300', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'חצי קומבי דיזל 1+6',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'קומבי דיזל 2+8 אוטוב',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUILANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'ספייס ואגון 4X4 אוטו',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  ...]

# %%
kinuy_mishari_mappings = {
    'OUILANDER': 'אאוטלנדר',
    'OUTLANDER': 'אאוטלנדר',
    'LANCER': 'לנסר',
    'ECLIPSE CROSS': 'אקליפס',
    'SPACE STAR': 'ספייס סטאר',
    'LANCER EVOLUTIO': 'לנסר איוולושן',
    'LANCER SPORTBAC': 'לנסר ספורטבק',
    'GRANDIS': 'גרנדיס',
    'ATTRAGE': "אטראז'",
    'COLT': 'קולט',
    'מיצובישי סופר לנסר I': 'סופר לנסר',
    'סופר לנסר ILG סלון': 'סופר לנסר'
}

# %%
for record in filtered_data:
    kinuy_mishari = record.get('kinuy_mishari', '')
    if kinuy_mishari in kinuy_mishari_mappings:
        record['kinuy_mishari'] = kinuy_mishari_mappings[kinuy_mishari]

# %%
api_df = pd.DataFrame(filtered_data)

# %%
api_df
# Out:
#          tozar kinuy_mishari  shnat_yitzur
# 0     מיצובישי     סופר לנסר          1996
# 1     מיצובישי     סופר לנסר          1996
# 2     מיצובישי     סופר לנסר          1997
# 3     מיצובישי     סופר לנסר          1997
# 4     מיצובישי      אאוטלנדר          2021
# ...        ...           ...           ...
# 1602  מיצובישי          לנסר          2008
# 1603  מיצובישי      אאוטלנדר          2020
# 1604  מיצובישי          לנסר          2009
# 1605  מיצובישי      אאוטלנדר          2022
# 1606  מיצובישי    ספייס סטאר          2022
#
# [1607 rows x 3 columns]

# %%
aggregated_data = api_df.groupby(['tozar', 'kinuy_mishari', 'shnat_yitzur']).size().reset_index(name='Supply_score')

# %%
aggregated_data
# Out:
#     manufactor                 model  Year  Supply_score
# 0     מיצובישי   004-L מיניבוס בנזין  1998             1
# 1     מיצובישי  004-L קומבי דיזל ידנ  1998             1
# 2     מיצובישי  004-L קומבי דיזל ידנ  1999             1
# 3     מיצובישי                   ASX  2011             2
# 4     מיצובישי                   ASX  2017             3
# ..         ...                   ...   ...           ...
# 260   מיצובישי        קומבי דיזל 1+3  1998             1
# 261   מיצובישי        קומבי דיזל 2+3  1998             1
# 262   מיצובישי        קומבי דיזל 2+6  1998             1
# 263   מיצובישי  קומבי דיזל 2+6 אוטוב  1998             1
# 264   מיצובישי  קומבי דיזל 2+8 אוטוב  1998             1
#
# [265 rows x 4 columns]

# %%
aggregated_data.rename(columns={'tozar': 'manufactor', 'kinuy_mishari': 'model', 'shnat_yitzur': 'Year'}, inplace=True)

# Merge DataFrames on the specified columns
merged_df = pd.merge(scrape_df, aggregated_data, on=['manufactor', 'model', 'Year'], how='left')

# Update the Supply_score in merged_df with the values from aggregated_data
merged_df['Supply_score'] = merged_df['Supply_score_y'].fillna(merged_df['Supply_score_x'])
merged_df['Supply_score'] = merged_df['Supply_score'].apply(pd.to_numeric,errors='coerce').astype('Int64')

# Drop the extra columns created during the merge
merged_df.drop(columns=['Supply_score_x', 'Supply_score_y'], inplace=True)

# %%
merged_df
# Out:
#     manufactor  Year           model  Hand      Gear  Engine_capacity  \
# 0     מיצובישי  2005     לנסר קלאסיק     8  אוטומטית             1600
# 1     מיצובישי  2016          GT3000     2  אוטומטית             2000
# 2     מיצובישי  2016          I-MIEV     2  אוטומטית             2000
# 3     מיצובישי  2020          אקליפס     2  אוטומטית             2000
# 4     מיצובישי  2010            לנסר     3  אוטומטית             1600
# ..         ...   ...             ...   ...       ...              ...
# 154   מיצובישי  2017        אאוטלנדר     1  אוטומטית             1998
# 155   מיצובישי  2020          אקליפס     1  אוטומטית             1500
# 156   מיצובישי  2010  לנסר הדור החדש     3  אוטומטית             1500
# 157   מיצובישי  2017        אאוטלנדר     2  אוטומטית             2000
# 158   מיצובישי  2015      ספייס סטאר     2  אוטומטית             1200
#
#     Engine_type Prev_ownership Curr_ownership             Area  \
# 0         בנזין          פרטית          פרטית  ירושלים והסביבה
# 1         בנזין          פרטית          פרטית  חיפה וחוף הכרמל
# 2         בנזין          פרטית          פרטית  חיפה וחוף הכרמל
# 3         בנזין         ליסינג          פרטית  חיפה וחוף הכרמל
# 4         בנזין          פרטית          פרטית    נתניה והסביבה
# ..          ...            ...            ...              ...
# 154       בנזין             NA             NA  מודיעין והסביבה
# 155       בנזין             NA             NA  מודיעין והסביבה
# 156       בנזין             NA             NA            קריות
# 157       בנזין             NA             NA  באר שבע והסביבה
# 158       בנזין          פרטית          פרטית  בית שמש והסביבה
#
#                    City     Price  Pic_num   Cre_date Repub_date  \
# 0               ירושלים    4700.0        3 2024-05-22 2024-05-27
# 1                   נשר   92000.0        4 2024-05-05 2024-05-05
# 2                   נשר   92000.0        4 2024-05-05 2024-05-04
# 3             טירת כרמל   85000.0        3 2024-04-25 2024-04-25
# 4                 נתניה   10000.0        7 2024-03-16 2024-03-16
# ..                  ...       ...      ...        ...        ...
# 154  מודיעין מכבים רעות  106000.0        0 2022-05-22 2022-05-22
# 155             מודיעין  129000.0        0 2022-05-11 2022-05-11
# 156               רכסים   11500.0        0 2022-05-05 2022-05-05
# 157             באר שבע  115000.0        0 2022-04-26 2022-04-26
# 158             בית שמש   36000.0        0 2022-01-13 2022-01-13
#
#                                            Description       Color      Km  \
# 0    רכב במצב פצצה שירת אותי נאמנה הוחלף לפני חודש ...        כסוף  230000
# 1    אאוטלנדר המפואר פרמיום 7 מקומות טופל אצל היבוא...         לבן  141000
# 2    אאוטלנדר הדגם המפואר 7 מקומות שמור ומטופל אצל ...         לבן  141000
# 3              מיצובישי ASX 76,000 ק"מ מוכן גם להחליף.        שחור   76000
# 4    גיר מנוע תקינים מעככת מוביליין רכב 7 שנים עצלי...        כסוף  242000
# ..                                                 ...         ...     ...
# 154  מצב מצויין, שמור, כל הטיפולים בסוכנות מיצובישי...          NA  122000
# 155             רכב שמור נמצא בחניה מקורה נהג יחיד(70)          NA   16000
# 156            חלונות שחורים מסך באגז גדול מושבים יפים          NA  220000
# 157  הרכב במצב מצויין טסט שלמה שלמה צלחות ברקסים וצ...          NA   85000
# 158  נהגת יחידה. אוטו שני בבית.הרכב במצב חדשש. 4צמי...  כסוף מטאלי     100
#
#      Test  Supply_score
# 0     141          <NA>
# 1    <NA>          <NA>
# 2     261          <NA>
# 3     110            15
# 4     171             9
# ..    ...           ...
# 154  <NA>            26
# 155  <NA>            15
# 156  <NA>          <NA>
# 157  <NA>            26
# 158  <NA>             5
#
# [159 rows x 20 columns]

# %%
merged_df.dtypes
# Out:
# manufactor                 object
# Year                        Int64
# model                      object
# Hand                        Int64
# Gear                     category
# Engine_capacity             Int64
# Engine_type              category
# Prev_ownership           category
# Curr_ownership           category
# Area                       object
# City                       object
# Price                     float64
# Pic_num                     Int64
# Cre_date           datetime64[ns]
# Repub_date         datetime64[ns]
# Description                object
# Color                      object
# Km                          Int64
# Test                        Int64
# Supply_score                Int64
# dtype: object

# %%
mydf = merged_df[(merged_df['Year'] >= 2017) & (merged_df['Year'] <= 2024)]

# %%
mydf.to_csv('mitsu17_24.csv',encoding='utf-8-sig',index=False)
