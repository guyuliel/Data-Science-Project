# %% [markdown]
# <table>
#   <tr>
#     <td>Guy Uliel</td>
#     <td>Rotem Dahan</td>
#   </tr>
#   <tr>
#     <td>318439908</td>
#     <td>316222215</td>
#   </tr>
# </table>

# %% [markdown]
# [GitHub Link](https://github.com/guyuliel/Data-Science-Project)

# %%
import requests
from bs4 import BeautifulSoup
from datetime import datetime
import calendar

# %%
import pandas as pd

# %%
import urllib.request
import urllib.parse
import json

# %% [markdown]
# ### Scraping Data

# %% [markdown]
# ##### We will insert the data into a list of dictionaries - each dictionary in the list represent an ad

# %%
def get_html(url):  # function that gets an HTML and response it back (Unreadable)
    try:
        response = requests.get(url)
        response.raise_for_status()  # Raise an error for bad status codes
        return response.text
    except requests.RequestException as e:
        print(f"Error fetching URL {url}: {e}")
        return None

def get_ad_urls(url):  # function that gets a URL (page) and for each page find all the URL ads and save them in a list
    try:
        html_content = get_html(url)
        if html_content is None:
            return []
        soup = BeautifulSoup(html_content, 'html.parser')
        cards = soup.find_all('div', class_='card-block')

        ad_urls = []
        for card in cards:
            # Stop processing once we reach the footer section
            if card.find_parent('footer'):
                break
            ad_url_tag = card.find('a', href=True)
            if ad_url_tag:
                ad_urls.append('https://www.ad.co.il' + ad_url_tag['href'])

        return ad_urls
    except Exception as e:
        print(f"Error parsing ad URLs from {url}: {e}")
        return []

def data_scrape(url):  # function that gets a URL and scrapes all the relevant data into a dictionary
    try:
        html_content = get_html(url)
        if html_content is None:
            return {}
        soup = BeautifulSoup(html_content, 'html.parser')

        vehicle_data = {}

        # Extract details from the table
        try:
            table = soup.find('table', class_='table table-sm mb-4')
            if table:
                rows = table.find_all('tr')
                for row in rows:
                    key_element = row.find_all('td')[0].text.strip()
                    value_element = row.find_all('td')[1].text.strip()
                    if key_element in ['ק"מ', 'נפח']:
                        value_element = value_element.replace(',', '')
                    vehicle_data[key_element] = value_element
        except AttributeError:
            print(f"Table not found on page {url}")

        # Extract manufacturer, model, and price
        try:
            card_body = soup.find('div', class_='card-body p-3')
            if card_body:
                titles = card_body.find_all('h2', class_='card-title')
                if len(titles) >= 2:
                    title_text = titles[0].text.strip()
                    price_text = titles[1].text.strip()
                    # Assuming the title contains the manufacturer and model
                    title_parts = title_text.split()
                    if len(title_parts) >= 2:
                        vehicle_data['יצרן'] = title_parts[0]  # Assuming the first word is the manufacturer
                        vehicle_data['דגם'] = ' '.join(title_parts[1:])  # The rest is the model
                    vehicle_data['מחיר'] = price_text.replace('₪', '').replace(',', '').strip()  # Remove the currency symbol, commas, and whitespace
        except AttributeError:
            print(f"Card body not found on page {url}")

        # Count the number of images in the gallery
        try:
            gallery_div = soup.find('div', class_='col-12 d-flex mt-3 justify-content-center flex-wrap', itemscope=True)
            if gallery_div:
                images = gallery_div.find_all('img')
                vehicle_data['מספר תמונות'] = len(images)
        except AttributeError:
            print(f"Gallery not found on page {url}")

        # Extract creation date and last bump date
        try:
            date_divs = soup.find_all('div', class_='px-3')
            if date_divs:
                for date_div in date_divs:
                    text = date_div.text.strip()
                    if 'תאריך יצירה' in text:
                        vehicle_data['תאריך יצירה'] = text.split(':')[-1].strip()
                    elif 'תאריך הקפצה אחרון' in text:
                        vehicle_data['תאריך הקפצה אחרון'] = text.split(':')[-1].strip()
        except AttributeError:
            print(f"Date divs not found on page {url}")

        # Extract description and clean it up
        try:
            meta_description = soup.find('meta', attrs={'name': 'description'})
            if meta_description and 'content' in meta_description.attrs:
                description = meta_description['content'].strip()
                # Clean up the description by replacing newline characters with spaces and reducing multiple spaces to a single space
                clean_description = ' '.join(description.split())
                vehicle_data['תיאור'] = clean_description
        except AttributeError:
            print(f"Meta description not found on page {url}")

        # Convert 'Test' date to days until the last day of the month
        try:
            test_date_str = vehicle_data.get('טסט עד')
            if test_date_str:
                test_date = datetime.strptime(test_date_str, '%m/%Y')
                last_day_of_month = datetime(test_date.year, test_date.month, calendar.monthrange(test_date.year, test_date.month)[1])
                days_until_last_day = (last_day_of_month - datetime.now()).days
                vehicle_data['טסט עד'] = days_until_last_day
        except (ValueError, TypeError):
            vehicle_data['טסט עד'] = 'Invalid date'

        return vehicle_data
    except Exception as e:
        print(f"Error scraping data from {url}: {e}")
        return {}

def get_next_page_url(soup):  # function that gets the next page URL
    try:
        next_page_tag = soup.find('li', class_='nextPage')
        if next_page_tag:
            next_page_link = next_page_tag.find('a', href=True)
            if next_page_link and 'href' in next_page_link.attrs:
                return 'https://www.ad.co.il' + next_page_link['href']
        return None
    except Exception as e:
        print(f"Error finding next page URL: {e}")
        return None

# %%
base_url = 'https://www.ad.co.il/car?sp261=13905'  # URL for Mitsubishi cars
url = base_url
mitsu = [] # the list of the dictionaries - each dictionary is an ad

while url != None:
    html_content = get_html(url) # we get the html file (unreadble) by using the function 'get_html'
    soup = BeautifulSoup(html_content, 'html.parser') # make it readable( HTML document) 
    ad_urls = get_ad_urls(url) # we get into list all the urls of the page i

    for ad_url in ad_urls:
        vehicle_data = data_scrape(ad_url) # we scrape each ad for page i (as a dictionary)
        mitsu.append(vehicle_data) # we add it into the list 
    # Get the URL of the next page
    url = get_next_page_url(soup) # we change the value of the url to be index + 1 (next page) 
    # And we go back to the while loop to do the same as we did - with the next page

# %%
mitsu
# Out:
# [{'שנה': '2005',
#   'יד': '8',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '230000',
#   'טסט עד': 140,
#   'צבע': 'כסוף',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '4700',
#   'מספר תמונות': 3,
#   'תאריך יצירה': '22/05/2024',
#   'תאריך הקפצה אחרון': '27/05/2024',
#   'תיאור': 'רכב במצב פצצה שירת אותי נאמנה הוחלף לפני חודש תושבות מנוע פלאגים ברקסים צלחות רפידות עבר טיפול 10000 ממש לאחרונה מזגן מקפיא רכב במצב מצוין פשוט תדלק וסע גמיש מע...'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '141000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'נשר',
#   'יצרן': 'מיצובישי',
#   'דגם': 'GT3000',
#   'מחיר': '92000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/05/2024',
#   'תאריך הקפצה אחרון': '05/05/2024',
#   'תיאור': 'אאוטלנדר המפואר פרמיום 7 מקומות טופל אצל היבואן שמור מאוד ללא תקלות ללא תאונות מרווח מאוד'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '141000',
#   'טסט עד': 260,
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'נשר',
#   'יצרן': 'מיצובישי',
#   'דגם': 'I-MIEV',
#   'מחיר': '92000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/05/2024',
#   'תאריך הקפצה אחרון': '04/05/2024',
#   'תיאור': 'אאוטלנדר הדגם המפואר 7 מקומות שמור ומטופל אצל היבואן ללא תאונות ללא תקלות רכב נח ומרווח מאוד גמיש מעט במחיר'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '76000',
#   'טסט עד': 109,
#   'צבע': 'שחור',
#   'בעלות קודמת': 'ליסינג',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'טירת כרמל',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '85000',
#   'מספר תמונות': 3,
#   'תאריך יצירה': '25/04/2024',
#   'תאריך הקפצה אחרון': '25/04/2024',
#   'תיאור': 'מיצובישי ASX 76,000 ק"מ מוכן גם להחליף.'},
#  {'שנה': '2010',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '242000',
#   'טסט עד': 170,
#   'צבע': 'כסוף',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'נתניה והסביבה',
#   'עיר': 'נתניה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '10000',
#   'מספר תמונות': 7,
#   'תאריך יצירה': '16/03/2024',
#   'תאריך הקפצה אחרון': '16/03/2024',
#   'תיאור': 'גיר מנוע תקינים מעככת מוביליין רכב 7 שנים עצלי ללא בעיה .'},
#  {'שנה': '2022',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '21500',
#   'צבע': 'כחול מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'נס ציונה - רחובות',
#   'עיר': 'רחובות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '129000',
#   'מספר תמונות': 6,
#   'תאריך יצירה': '06/02/2024',
#   'תאריך הקפצה אחרון': '06/02/2024',
#   'תיאור': 'דגם executive מנוע 1.5 טורבו מפתח חכם כניסה והתנעה טסט וטיפול עד 7/2024 רכב נקי מתאונות עדיין באחריות יצרן!'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חדרה וישובי עמק חפר',
#   'עיר': 'חדרה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'דימונה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'עכו - נהריה',
#   'עיר': 'נהריה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'רעננה - כפר סבא',
#   'עיר': 'כפר סבא',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'נתניה והסביבה',
#   'עיר': 'נתניה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '4200',
#   'סוג מנוע': 'גז',
#   'ק"מ': '90000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'רעננה - כפר סבא',
#   'עיר': 'כפר סבא',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '35000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '05/01/2024',
#   'תאריך הקפצה אחרון': '05/01/2024',
#   'תיאור': '2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנוע 4 צילינדרים חזק בנפח 2.0 ליטר עם תיבת הילוכים אוטומטית, הנעה לכל הגלגלים לְנַקוֹת, ללא תאונות 90,000 מיילים מה...'},
#  {'שנה': '2008',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '237000',
#   'צבע': 'כחול',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '7500',
#   'מספר תמונות': 6,
#   'תאריך יצירה': '06/11/2023',
#   'תאריך הקפצה אחרון': '17/12/2023',
#   'תיאור': 'לרציניים בלבד!! מוכר את הרכב שלי בצער רב. האוטו ללא תאונות יש לו מצבר+אלטרנטור חדשים עם ביטוח, מזגן עובד קור וחום אפשר להתחבר למערכת גם עם כבל USB ויש רמקולים ...'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '29000',
#   'צבע': 'לבן שנהב',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '12000',
#   'מספר תמונות': 2,
#   'תאריך יצירה': '28/11/2023',
#   'תאריך הקפצה אחרון': '28/11/2023',
#   'תיאור': 'מיציבושי אאוטלנדר דגם אינסטיל. 7 מקומות. ללא תאונות. גגון. כספת'},
#  {'שנה': '2011',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '170000',
#   'צבע': 'שחור',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'גליל ועמקים',
#   'עיר': 'נצרת עילית',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר איוולושן',
#   'מחיר': '13000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '16/11/2023',
#   'תאריך הקפצה אחרון': '16/11/2023',
#   'תיאור': 'רכב כמו חדש , מצויין , חיסכוני , טסט עד 05/2024 170,000 ק״ם'},
#  {'שנה': '2014',
#   'יד': '5',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '193000',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין מכבים רעות',
#   'יצרן': 'מיצובישי',
#   'דגם': "אטראז'",
#   'מחיר': '16000',
#   'מספר תמונות': 5,
#   'תאריך יצירה': '23/10/2023',
#   'תאריך הקפצה אחרון': '25/10/2023',
#   'תיאור': 'רכב במצב מעולה כמו חדש. אמין,לא רואה מוסך,חסכוני בדלק. לאחר טיפול תקופתי מקיף,מצבר חדש,צמיגים חדשים. תא מטען ענק ,מזגן מקפיא. טסט עד פברואר. מחירון לוי יצחק 19,...'},
#  {'שנה': '2018',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '48500',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'יצרן': 'מיצובישי',
#   'דגם': "אטראז'",
#   'מחיר': '119000',
#   'מספר תמונות': 3,
#   'תאריך יצירה': '22/08/2023',
#   'תאריך הקפצה אחרון': '22/08/2023',
#   'תיאור': 'מיצובישי אאוטלנדר 2018 , 7 מקומות דגם INSTYLE, יד פרטית ראשונה, ללא תאונות. קילומטראז נמוך 48,000. שמורה ומטופלת במוסך היבואן. 119,000 ש"ח. שי 0506776388'},
#  {'שנה': '2009',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1800',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '183000',
#   'צבע': 'שחור',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '17000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '09/07/2023',
#   'תאריך הקפצה אחרון': '09/07/2023',
#   'תיאור': 'הרכב אמין, שמור ומטופל, מצבר חדש ממש, מסך מולטימדיה גדול ואיכותי, מצלמת רוורס, מנוע 1800(!).'},
#  {'שנה': '2005',
#   'יד': '3',
#   'ת. הילוכים': 'טיפטרוניק',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '225000',
#   'צבע': 'כסוף',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'בית שמש והסביבה',
#   'עיר': 'בית שמש',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '7250',
#   'מספר תמונות': 7,
#   'תאריך יצירה': '15/05/2023',
#   'תאריך הקפצה אחרון': '15/05/2023',
#   'תיאור': 'רכב שמור ללא תקלות יש טסט ל 7 חודש מזגן מקפיא יש לרכב שני מפתחות ושני שלטים בשווי כל אחד 300 שקלים מערכת שמע טובה מאוד עם בלוטוס מגיע עם שואב אבק שמתחבר למצת ש...'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2400',
#   'סוג מנוע': 'היבריד',
#   'ק"מ': '64000',
#   'צבע': 'כסוף מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'גדרה יבנה והסביבה',
#   'עיר': 'יבנה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'I-MIEV',
#   'מחיר': '141000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '15/05/2023',
#   'תאריך הקפצה אחרון': '15/05/2023',
#   'תיאור': 'מיצובישי אאוטלנדר PHEV פלאג אין, שמורה ונקיה, טופלה במוסך היבואן, ק"מ נמוך, צמיגים חדשים'},
#  {'שנה': '2012',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '215000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חדרה וישובי עמק חפר',
#   'עיר': 'חדרה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '15000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '13/05/2023',
#   'תאריך הקפצה אחרון': '13/05/2023',
#   'תיאור': 'Mitsubishi Lancer Instyle 2012 1.6 יד 2 215,000 ק"מ טסט: 09 ברכב קיימת מערכת מולטימדיה Android 9.1 סאב חברת Pioneer ו2 אמפליפיירים מחברת Logic רכב מעולה לא עוש...'},
#  {'שנה': '2008',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '260000',
#   'צבע': 'אפור מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '8000',
#   'מספר תמונות': 3,
#   'תאריך יצירה': '25/03/2023',
#   'תאריך הקפצה אחרון': '25/03/2023',
#   'תיאור': 'לרכב הוחלף לאחרונה טיימינג משאבת מים בלמים קדימה תושבות גיר קדימה ואחורה שמנים ופילטרים'},
#  {'שנה': '2007',
#   'יד': '5',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '194400',
#   'צבע': 'אפור מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '7700',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '25/03/2023',
#   'תאריך הקפצה אחרון': '25/03/2023',
#   'תיאור': 'רכב במצב מצוין הוחלף לאחרונה טיימינג משאבת מים שמנים ופילטרים בלמים אחורה וקדימה תושבות מנוע'},
#  {'שנה': '2018',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1400',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '95000',
#   'צבע': 'כחול',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '42500',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '17/02/2023',
#   'תאריך הקפצה אחרון': '17/02/2023'},
#  {'שנה': '2016',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '206000',
#   'צבע': 'לבן מטאלי',
#   'בעלות קודמת': 'אחר',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין מכבים רעות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'I-MIEV',
#   'מחיר': '1',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '07/12/2022',
#   'תאריך הקפצה אחרון': '12/01/2023',
#   'תיאור': 'מיצובישי אאוטלנדר במצב טוב שמור ,לא עבר תאונות, טיפולים לפי הספר, מתחייב בבדיקה לרצינים בלבד פרטים בטלפון \u200e0542458443'},
#  {'שנה': '2008',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '200000',
#   'צבע': 'אפור מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'נס ציונה - רחובות',
#   'עיר': 'רחובות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '7500',
#   'מספר תמונות': 6,
#   'תאריך יצירה': '27/12/2022',
#   'תאריך הקפצה אחרון': '27/12/2022',
#   'תיאור': 'Lancer 2008 יד3 טסט 3/23 200קמ מצב מכני מצויין+ נסיעה שקטה, הכל עובד מעולה הנחות לנהגים חדשים, חיילים ועולים חדשים‼️ Скидки новым репатриантам ‼️'},
#  {'שנה': '2018',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '74000',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'גבעתיים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '123000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '29/10/2022',
#   'תאריך הקפצה אחרון': '29/10/2022',
#   'תיאור': 'מיצובישי ג\'יפ אאוטלנדר 7 מושבים נוסעים, שנת 2018 יד 2 לאחר טיפול במוסך מיצובישי. 74,000 ק"מ ללא תאונות. מערכת אנדרואיד מסך גדול, חלון בגג, ג\'אנטים מגנזיום, צמ...'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2360',
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '93000',
#   'אזור': 'גליל ועמקים',
#   'עיר': 'יוקנעם עילית',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '165000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '27/10/2022',
#   'תאריך הקפצה אחרון': '27/10/2022',
#   'תיאור': 'דגם סופרים הכי מפואר פלאג אין phev'},
#  {'שנה': '2015',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '213000',
#   'אזור': 'יישובי השומרון',
#   'עיר': 'עץ אפרים',
#   'יצרן': 'מיצובישי',
#   'דגם': "אטראז'",
#   'מחיר': '26000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '27/10/2022',
#   'תאריך הקפצה אחרון': '27/10/2022',
#   'תיאור': 'רכב במצב מעולה טסט לשנה. יד 1 ליסינג יד 2 פרטי מנכה. שמור מאד גלגלים חדשים מערכת מולטימדיה מצלמת דרך. &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מערכת מולטימדיה,...'},
#  {'שנה': '2021',
#   'יד': '1',
#   'ת. הילוכים': 'טיפטרוניק',
#   'נפח': '2500',
#   'סוג מנוע': 'היברידי',
#   'ק"מ': '25500',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין מכבים רעות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '207000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '26/10/2022',
#   'תאריך הקפצה אחרון': '26/10/2022',
#   'תיאור': 'מצב מצויין שמור מאוד &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מערכת הגברה'},
#  {'שנה': '2008',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1800',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '300000',
#   'צבע': 'זהב מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'עמק יזרעאל',
#   'עיר': 'גן נר',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר ספורטבק',
#   'מחיר': '18000',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '24/10/2022',
#   'תאריך הקפצה אחרון': '24/10/2022',
#   'תיאור': 'דגם: לנסר ספורט החדשה מזגן מעולה תא מיטען ענק יושבת מצוין על הכביש מאוד אמינה ונוחה בטיחות מירבית (7 כריות אוויר).'},
#  {'שנה': '2014',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '17777',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'קרית גת',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '65000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '24/10/2022',
#   'תאריך הקפצה אחרון': '24/10/2022',
#   'תיאור': 'רכב מושלם ושמר מטופל בזמן במוסך מורשה מוכר כי קניתי אותו על חשמל יש בעיה בחלון ליד הנהג לכן אני קצת גמיש לעוד פרטים בפרטי &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt...'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '80',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '115000',
#   'אזור': 'אילת והערבה',
#   'עיר': 'אילת',
#   'יצרן': 'מיצובישי',
#   'דגם': "אטראז'",
#   'מחיר': '60000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '23/10/2022',
#   'תאריך הקפצה אחרון': '23/10/2022',
#   'תיאור': 'הרחב במצב טוב ללא תעונות במצב טוב שמור לחלוטין'},
#  {'שנה': '2017',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '58000',
#   'אזור': 'נס ציונה - רחובות',
#   'עיר': 'נס ציונה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '110000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '23/10/2022',
#   'תאריך הקפצה אחרון': '23/10/2022',
#   'תיאור': 'יד ראשונה פרטית , מצב מצויין ללא תאונות'},
#  {'שנה': '2021',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '30000',
#   'אזור': 'חולון - בת ים',
#   'עיר': 'חולון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '165000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '21/10/2022',
#   'תאריך הקפצה אחרון': '21/10/2022',
#   'תיאור': 'דגם הפרימיום היוקרתי. כולל ציפוי ננו קרמי, חימום במושבים, שבעה מושבים, גג נפתח, באחריות יצרן עד מרץ 2023,שמור ביותר, איתוראן אקטיב, מרימי שמשות וסוגר גג. מערכות...'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'טיפטרוניק',
#   'נפח': '2500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '40000',
#   'אזור': 'חולון - בת ים',
#   'עיר': 'חולון',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '20/10/2022',
#   'תאריך הקפצה אחרון': '20/10/2022',
#   'תיאור': 'רכב שמור מטופל בחברה בזמן &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; וו גרירה'},
#  {'שנה': '2017',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '180000',
#   'עיר': 'גבעת עדה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '95000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '19/10/2022',
#   'תאריך הקפצה אחרון': '19/10/2022',
#   'תיאור': 'רכב במצב מעולה, דגם Instyle, עבר את כל הטיפולים במוסך מיצובישי מורשה, 7 מושבים, כולל מובילאי, מערכת מולטימדיה מקורית, גג נפתח, בעלות קודמת ליסינג 0 ק"מ והיה ביד...'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '163000',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '100000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '19/10/2022',
#   'תאריך הקפצה אחרון': '19/10/2022',
#   'תיאור': 'מיצובישי אאוטלנדר תאריך עלייה לכביש 10.08.2016... 163,000 קילומטר.... קיים תיק טיפולים + טסט לשנה ... 7 מקומות.'},
#  {'שנה': '2020',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1650',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '80000',
#   'עיר': 'רמות מאיר',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '107000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '19/10/2022',
#   'תאריך הקפצה אחרון': '19/10/2022',
#   'תיאור': 'רכב במצב מצויין'},
#  {'שנה': '2018',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '9000',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '126000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '18/10/2022',
#   'תאריך הקפצה אחרון': '18/10/2022',
#   'תיאור': 'אאוטלנדר אינסטנט כחדש דצמבר 2018 . נסע רק 9000 קמ . התחיבות למנוע גיר ושסי.'},
#  {'שנה': '2021',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '34000',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '159000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '18/10/2022',
#   'תאריך הקפצה אחרון': '18/10/2022',
#   'תיאור': 'מכונית חדשה מרהיבה ועוצמתית באחריות החברה- עם כל התוספות המתבקשות.'},
#  {'שנה': '2010',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '240000',
#   'אזור': 'פרדס חנה - כרכור',
#   'עיר': 'פרדס חנה כרכור',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר הדור החדש',
#   'מחיר': '12000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '17/10/2022',
#   'תאריך הקפצה אחרון': '17/10/2022',
#   'תיאור': 'מצב מכני מעולה, טסט עד אוגוסט 2023, יד שניה'},
#  {'שנה': '2009',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '199000',
#   'צבע': 'כסוף מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'עתלית',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '14000',
#   'מספר תמונות': 5,
#   'תאריך יצירה': '25/06/2022',
#   'תאריך הקפצה אחרון': '15/10/2022',
#   'תיאור': 'מיצובישי לנסר הדור החדש 2009 1500 סמ"ק בצבע כסף,טסט לשנה, אוטו במצב מעולה, אמין מאוד, מטופל תמיד בזמן עם חלפים מקוריים. אצלי 8 שנים שימש אותי נאמנה ללא תקלות. כ...'},
#  {'שנה': '2013',
#   'יד': '4',
#   'ת. הילוכים': 'טיפטרוניק',
#   'נפח': '255',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '239',
#   'אזור': 'אשדוד - אשקלון',
#   'עיר': 'אשקלון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '65000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '14/10/2022',
#   'תאריך הקפצה אחרון': '14/10/2022',
#   'תיאור': 'מיצובישי אאוטלנדר במצב מעולה הדגם המשופר Elite 4 על 4 ריפודי עור, חימום במושבים, מערכת אנדרואיד חדשה ברכב, וו גרירה, גגון כל התוספות של הדגם המפואר &lt;br/&g...'},
#  {'שנה': '2010',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2400',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '400000',
#   'אזור': 'בית שמש והסביבה',
#   'עיר': 'בית שמש',
#   'יצרן': 'מיצובישי',
#   'דגם': 'גרנדיס',
#   'מחיר': '35000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '13/10/2022',
#   'תאריך הקפצה אחרון': '13/10/2022',
#   'תיאור': 'רכב חזק אמין ונוח במיוחד. תא מטען ענק בקיפול המושבים הוא פשוט עצום. בגרסת הבסיס הרכב שותה דלק ולכן עבר הסבה לגז שנותנת נתונים של 1 ל15 כשעבור רכב בגודל הזה זה נ...'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '41000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '99000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '07/10/2022',
#   'תאריך הקפצה אחרון': '07/10/2022',
#   'תיאור': 'למכירה מציאה של ממש** אאוטלנדר 2016 5 מקומות כמו חדש קילומטראז רק 39 אלף פרטית ..עם תוספות מדרכות צד ניקל איכותיות ומולטימדיה 10 כל האפליקציות פתוחות ..רכב חסכו...'},
#  {'שנה': '2008',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1800',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '189',
#   'עיר': 'יקנעם עילית',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '16900',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '07/10/2022',
#   'תאריך הקפצה אחרון': '07/10/2022',
#   'תיאור': 'מיצובישי לנסר 2008 רכב שמור מאוד טיפולים בזמן צבע די שמור נהגת יחידה מוכרת עקב מעבר לרכב חדש יותר הוחלף צמיגים, משולשים, תפוחים, הכל חדש רכב חזק מנוע 1800 יש את...'},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '20000',
#   'אזור': 'רעננה - כפר סבא',
#   'עיר': 'כוכב יאיר',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '67000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '06/10/2022',
#   'תאריך הקפצה אחרון': '06/10/2022',
#   'תיאור': 'טסט אוקטובר 2023! מצב מצוין, ק"מ נמוך, נהגת יחידה ניתן לראות בהרצליה/כוכב יאיר/תל אביב &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מצלמת רוורס car play'},
#  {'שנה': '2018',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '73000',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'גבעתיים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '131000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '05/10/2022',
#   'תאריך הקפצה אחרון': '05/10/2022',
#   'תיאור': "ג'יפ מיצובישי אאוטלנדר 7 מקומות , אינסטייל , הנעה בכפתור ללא מפתח , חלון בגג , מערכת מולטימדיה אנדרואיד, טיפולים במוסך מיצובישי."},
#  {'שנה': '2015',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '109000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'שדרות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '94000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '05/10/2022',
#   'תאריך הקפצה אחרון': '05/10/2022',
#   'תיאור': 'רכב שמור מטופל בזמן 2 נהגים בלבד עבר בדיקה לפני שבועיים טסט עד 12/22 &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מצלמת רוורס'},
#  {'שנה': '2017',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '90000',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '115000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '04/10/2022',
#   'תאריך הקפצה אחרון': '04/10/2022',
#   'תיאור': 'מטופל בחברה'},
#  {'שנה': '2020',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '26800',
#   'צבע': 'שחור',
#   'בעלות קודמת': 'חברה',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'נתניה והסביבה',
#   'עיר': 'נתניה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '70900',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '02/10/2022',
#   'תאריך הקפצה אחרון': '02/10/2022',
#   'תיאור': 'מציאה!! רכב שמור מאוד במצב מדהים נהגת יחידה עם מספר שלא תמצאו באף רכב שמור היטב מטופל רק בחברה.. לרצינים לפנות!! קילומטר נמוך!! 0504055111'},
#  {'שנה': '2017',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '92000',
#   'עיר': 'ניר עציון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '102000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '28/09/2022',
#   'תאריך הקפצה אחרון': '28/09/2022',
#   'תיאור': 'רכב יד שניה, ללא תאונות, 7 מקומות, עשה טסט בחודש אוגוסט, צמיגים חדשים.'},
#  {'שנה': '2021',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '17000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '165000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '26/09/2022',
#   'תאריך הקפצה אחרון': '26/09/2022',
#   'תיאור': 'רכב שמור מאוד'},
#  {'שנה': '2010',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '177000',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '42000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '22/09/2022',
#   'תאריך הקפצה אחרון': '22/09/2022',
#   'תיאור': 'רכב שמור, צמיגים חדשים, מצבר חדש, טסט לשנה.'},
#  {'שנה': '1990',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1468',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '240000',
#   'אזור': 'ראש העין והסביבה',
#   'עיר': 'אלעד',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '6000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '21/09/2022',
#   'תאריך הקפצה אחרון': '21/09/2022',
#   'תיאור': 'אספנות נוסע מעולה טסט פעם בשנה ביטוח ממש זול מזגן מחבר חדש'},
#  {'שנה': '2022',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '300',
#   'אזור': 'רמלה - לוד',
#   'עיר': 'לוד',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ASX',
#   'מחיר': '150000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '21/09/2022',
#   'תאריך הקפצה אחרון': '21/09/2022',
#   'תיאור': 'רכב חדש מהניילון חודש על הכביש קילומטר נמוך,תוספות גג חשמלי נפתח,חלונות חשמליים,מערכת מולטימדיה,חיישני קורס,משענת יד מושקעת. &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/...'},
#  {'שנה': '2008',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1584',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '153678',
#   'אזור': 'אשדוד - אשקלון',
#   'עיר': 'אשקלון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '12000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '19/09/2022',
#   'תאריך הקפצה אחרון': '19/09/2022',
#   'תיאור': "רכב במצב טוב. נהג הרכב יחיד. טסט מסתיים בעוד חודש. קילומרז' נמוך. יד ראשונה -ליסינג."},
#  {'שנה': '2020',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '28000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ASX',
#   'מחיר': '123000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '16/09/2022',
#   'תאריך הקפצה אחרון': '16/09/2022',
#   'תיאור': 'דגם פרימיום , חימום מושבים , גג פנורמי , מסך מולטימדיה, מושבי עור'},
#  {'שנה': '2016',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '128585',
#   'אזור': 'אשדוד - אשקלון',
#   'עיר': 'אשדוד',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '109500',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '16/09/2022',
#   'תאריך הקפצה אחרון': '16/09/2022',
#   'תיאור': 'יד 02 ליסינג תפעולי נהג יחיד לשעבר מנוע 1.99 בנזין 150 כס גימור אינסטייל צבע כסף 128,585 קמ 7 מקומות תוספות: וו גרירה, חיבור חשמל, מערכת Mobil Eye ...'},
#  {'שנה': '2021',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '10000',
#   'אזור': 'חדרה וישובי עמק חפר',
#   'עיר': 'חדרה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ASX',
#   'מחיר': '135000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '16/09/2022',
#   'תאריך הקפצה אחרון': '16/09/2022',
#   'תיאור': 'מיצובישי מסוג asx מודל 2021, יד ראשונה מפרטי , לפרטיי יש ליצור קשר 0522661185 &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מצלמה , איתורן, מגיני צד'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '115000',
#   'אזור': 'אשדוד - אשקלון',
#   'עיר': 'אשדוד',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '110000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '14/09/2022',
#   'תאריך הקפצה אחרון': '14/09/2022',
#   'תיאור': 'ב"ה 7 מקומות שמור מאוד לאחר טיפול גדול במיציבושי טסט לשנה. +גגון. ריפודים במצב חדש.'},
#  {'שנה': '2008',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1300',
#   'סוג מנוע': 'בנזין',
#   'אזור': 'טבריה והסביבה',
#   'עיר': 'טבריה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '6000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '13/09/2022',
#   'תאריך הקפצה אחרון': '13/09/2022',
#   'תיאור': 'מיציבושי לנסר במצב מצוין טסט לשנה'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '129560',
#   'עיר': 'נחושה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '87000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '12/09/2022',
#   'תאריך הקפצה אחרון': '12/09/2022',
#   'תיאור': 'רכב פשוט מעולה! נאלצים להיפרד כיוון שכבר לא זקוקים ל7 מקומות ולכן עוברים למשפחתי. אתם תהנו ממנו!'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '150',
#   'עיר': 'שעב',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '11/09/2022',
#   'תאריך הקפצה אחרון': '11/09/2022'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '150',
#   'עיר': 'שעב',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '11/09/2022',
#   'תאריך הקפצה אחרון': '11/09/2022',
#   'תיאור': "מיצופישי אווט לנדר 2016 150 ק'ש 7 מושבים גג"},
#  {'שנה': '2016',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '123500',
#   'אזור': 'רעננה - כפר סבא',
#   'עיר': 'כפר סבא',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '105000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '10/09/2022',
#   'תאריך הקפצה אחרון': '10/09/2022',
#   'תיאור': 'רכב עם נהג יחיד בכל התקופה, ללא תאונות למעט שריטות. טסט עד יוני 2023'},
#  {'שנה': '2009',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '130000',
#   'אזור': 'הוד השרון והסביבה',
#   'עיר': 'הוד השרון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר הדור החדש',
#   'מחיר': '15000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '10/09/2022',
#   'תאריך הקפצה אחרון': '10/09/2022',
#   'תיאור': "רכב יד ראשונה, קילומטרג' נמוך. גמיש במחיר."},
#  {'שנה': '2020',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '15500',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '132000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '07/09/2022',
#   'תאריך הקפצה אחרון': '07/09/2022',
#   'תיאור': 'רכב חדש לחלוטין, שמור מאוד, קילומטרז אפסי, nbug 1500 yurcu\' מטופל במוסף נירון מוטורס פ"ת. עבר טסט וטיפול כעת כך שיש עוד שנה לטסט ולטיפול הבא, מערכות סטיית נתיב ...'},
#  {'שנה': '2016',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '36000',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '110000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '06/09/2022',
#   'תאריך הקפצה אחרון': '06/09/2022',
#   'תיאור': 'טסט לשנה , צמיגים חדשים , מערכת שמע מקורית מעולה, חניה בחניון מקורה'},
#  {'שנה': '2020',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '56000',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '131000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '06/09/2022',
#   'תאריך הקפצה אחרון': '06/09/2022',
#   'תיאור': 'יד ראשונה פרטית, רכב חדש לגמרי,שמור ומטופל,ללא תאונות, אחריות יצרן מלאה על הרכב,מערכת מולטימדייה, גג נפתח כפול נהג יחיד, ללא תאונות. לרציניים בלבד. &lt;br/&g...'},
#  {'שנה': '2008',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '240',
#   'אזור': 'טבריה והסביבה',
#   'עיר': 'קצרין',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '8000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '04/09/2022',
#   'תאריך הקפצה אחרון': '04/09/2022',
#   'תיאור': 'רכב פצצה לאחר טיימינג משאבת מים ועוד…'},
#  {'שנה': '2018',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1400',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '63358',
#   'עיר': 'ראשון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '120000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '04/09/2022',
#   'תאריך הקפצה אחרון': '04/09/2022',
#   'תיאור': 'דגם מפואר גג פנורמי ריפודים מעור רכב שמור'},
#  {'שנה': '2017',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '118000',
#   'עיר': 'מעלה עירון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '93000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '04/09/2022',
#   'תאריך הקפצה אחרון': '04/09/2022',
#   'תיאור': 'רכב שמור במצב טוב . לסינג לשעבר'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '105000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '03/09/2022',
#   'תאריך הקפצה אחרון': '03/09/2022',
#   'תיאור': 'למכירה מציאה של ממש** אאוטלנדר 2016 דגם אינטנס 5 מקומות כמו חדש קילומטראז רק 39 אלף פרטית ..עם תוספות מדרכות צד ניקל איכותיות ומולטימדיה 10 כל האפליקציות פתוחות...'},
#  {'שנה': '2016',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '85000',
#   'אזור': 'אילת והערבה',
#   'עיר': 'אילת',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '100000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '03/09/2022',
#   'תאריך הקפצה אחרון': '03/09/2022',
#   'תיאור': 'מצב טוב מאוד. נהג יחיד. כל טיפולים בזמן. ללא תאונות.'},
#  {'שנה': '2019',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '40000',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ASX',
#   'מחיר': '95000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '31/08/2022',
#   'תאריך הקפצה אחרון': '31/08/2022',
#   'תיאור': 'רכב שמור נהג יחיד כולל מערכת מולטי מדיה מקורית. קילומטרז נמוך. מטופל במיצובישי'},
#  {'שנה': '2010',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2400',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '360000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'נתיבות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'גרנדיס',
#   'מחיר': '18000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '29/08/2022',
#   'תאריך הקפצה אחרון': '29/08/2022',
#   'תיאור': 'דרושה רק החלפת מנוע והמחיר בהתאם הרכב עם מערכת גז לאחר טיפול גדול'},
#  {'שנה': '2017',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '153000',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '110000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '29/08/2022',
#   'תאריך הקפצה אחרון': '29/08/2022',
#   'תיאור': 'רכב שמור מאד, מטופל במוסך היבואן, ללא תאונות,נהג יחיד,5 מקומות'},
#  {'שנה': '2018',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '71000',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'רמת גן',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ASX',
#   'מחיר': '80000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '29/08/2022',
#   'תאריך הקפצה אחרון': '29/08/2022',
#   'תיאור': 'רכב במצב מצוין, לאחר טיפול גדול והחלפת צמיגים (מישלין 4 גלגלים) לרציניים בלבד .'},
#  {'שנה': '2017',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '57000',
#   'צבע': 'כסוף',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'עיר': 'מתתיהו',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '38500',
#   'מספר תמונות': 3,
#   'תאריך יצירה': '28/08/2022',
#   'תאריך הקפצה אחרון': '28/08/2022',
#   'תיאור': 'אמין וחסכוני.... והמחיר הוא סופי....'},
#  {'שנה': '2011',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2400',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '147000',
#   'עיר': 'באקה אל-גרביה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'גרנדיס',
#   'מחיר': '40000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '23/08/2022',
#   'תאריך הקפצה אחרון': '23/08/2022'},
#  {'שנה': '2011',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2400',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '138000',
#   'עיר': 'באקה אל-גרביה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'גרנדיס',
#   'מחיר': '37000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '23/08/2022',
#   'תאריך הקפצה אחרון': '23/08/2022'},
#  {'שנה': '2017',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1193',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '96509',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '44000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '20/08/2022',
#   'תאריך הקפצה אחרון': '20/08/2022',
#   'תיאור': 'שמור, מטופל בזמן, לא רואה מוסך, חסכוני מאד בדלק, מכונית זריזה ונוחה לנסיעה עירונית ובינעירונית. &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; 4 חלונות חשמליים, נעילה ...'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '45000',
#   'אזור': 'בקעת אונו',
#   'עיר': 'יהוד מונוסון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '147000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '18/08/2022',
#   'תאריך הקפצה אחרון': '18/08/2022',
#   'תיאור': "בהזדמנות שמורה כחדשה מטופלת בחברה. מטרז' נמוך, מצלמה קידמית מתנה. לא בשבת &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מצלמת רוורס מצלמה קידמית גג נפתח"},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '122000',
#   'אזור': 'נתניה והסביבה',
#   'עיר': 'נתניה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '119000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '17/08/2022',
#   'תאריך הקפצה אחרון': '17/08/2022',
#   'תיאור': 'הרכב שמור במצב חדש עבר שטיפה ומחכה לבעלים הבאים נמכר עקב קבלת רכב מהעבודה האוטו שמור במצב חדש יד 2 ריפודי עור חלונות כהים מגנזיום 7 מקומות הכול כחדש'},
#  {'שנה': '2011',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '199',
#   'אזור': 'חיפה וחוף הכרמל',
#   'עיר': 'חיפה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר החדשה',
#   'מחיר': '15500',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '16/08/2022',
#   'תאריך הקפצה אחרון': '16/08/2022',
#   'תיאור': 'מיצובישי לנסר שליטה מהגה אוטו חסכוני שמור ומטופל בשמנים אחי טובים'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '50000',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '137000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '15/08/2022',
#   'תאריך הקפצה אחרון': '15/08/2022',
#   'תיאור': 'רכב במצב מצוין, עבר כל הטיפולים במוסך המרכזי של מיצובישי, ללא תאונות, מכירה מיידית.'},
#  {'שנה': '2016',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '33560',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'רמת גן',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '123000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '13/08/2022',
#   'תאריך הקפצה אחרון': '13/08/2022',
#   'תיאור': 'שמור מאוד.'},
#  {'שנה': '2018',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '81000',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '140000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '12/08/2022',
#   'תאריך הקפצה אחרון': '12/08/2022',
#   'תיאור': 'טסט לשנה, שמור כחדש , טיפולים בזמן'},
#  {'שנה': '2011',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1800',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '161000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '24000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '12/08/2022',
#   'תאריך הקפצה אחרון': '12/08/2022',
#   'תיאור': 'מיצובישי לנסר ספורט. יד ראשונה. רכב מטופל.'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'טיפטרוניק',
#   'נפח': '2500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '37000',
#   'אזור': 'חולון - בת ים',
#   'עיר': 'חולון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '145000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '11/08/2022',
#   'תאריך הקפצה אחרון': '11/08/2022',
#   'תיאור': 'רכב 7 מקומות אינסטייל,גג נפתח,ריפודים,וו גרירה רכב חדש'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1989',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '250000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '04/08/2022',
#   'תאריך הקפצה אחרון': '04/08/2022',
#   'תיאור': 'שלום רכב במצב מצוין בלי תאונות שמור'},
#  {'שנה': '2014',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '200',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '69000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '03/08/2022',
#   'תאריך הקפצה אחרון': '03/08/2022',
#   'תיאור': 'רכב נהדר במצב מעולה! גרסה מפוארת 4X4 עם ריפוד עוד מושבים מתכווננים חשמלית עם חימום. נמכר עקב מעבר לרכב מותאם לנכה. (גמיש מעט במחיר במעמד המכירה) &lt;br...'},
#  {'שנה': '2017',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '67000',
#   'אזור': 'חולון - בת ים',
#   'עיר': 'בת ים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '42000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '01/08/2022',
#   'תאריך הקפצה אחרון': '01/08/2022'},
#  {'שנה': '2011',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '111000',
#   'אזור': 'נס ציונה - רחובות',
#   'עיר': 'נס ציונה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר הדור החדש',
#   'מחיר': '20000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '31/07/2022',
#   'תאריך הקפצה אחרון': '31/07/2022',
#   'תיאור': 'יד 2 אבל אותם בעלים כמו ראשונה ( נוסף בעלים נוסף) במצב מעולה. ללא תאונות. טופל כל השנים במוסך מורשה של מיצובישי'},
#  {'שנה': '2020',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '51600',
#   'אזור': 'הוד השרון והסביבה',
#   'עיר': 'הוד השרון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ASX',
#   'מחיר': '118000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '30/07/2022',
#   'תאריך הקפצה אחרון': '30/07/2022',
#   'תיאור': 'דגם פרמיום. ללא תאונות ותיקונים. טיפולים במוסך מורשה של היבואן. נהג יחיד וותיק ומנוסה . &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; גג פנוראמי, מושבי עור, פנסי LED,...'},
#  {'שנה': '2008',
#   'יד': '5',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '250000',
#   'אזור': 'ראש העין והסביבה',
#   'עיר': 'ראש העין',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '6000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '29/07/2022',
#   'תאריך הקפצה אחרון': '29/07/2022',
#   'תיאור': 'מיצובישי לנסר שנת 2008. 251 אלף קילומטר. יד 5 טסט עד סוף ינואר 2023. רכב שמור מאוד ומושקע. מצבר חדש באחריות נעשה טיימינג וטיפול. מחיר נמוך עקב תקלה שאין לי זמן ...'},
#  {'שנה': '2018',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '50000',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '140000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '27/07/2022',
#   'תאריך הקפצה אחרון': '27/07/2022',
#   'תיאור': 'mitsubishi outlander instyle 2018 7 seater מיצובישי אאוטלנדר אינסטייל 7 מקומות נהג יחיד 50,000 קמ טיפולים במוסך מורשה. טיפול הבא 7/23 טסט עד סוף 1/23 &...'},
#  {'שנה': '2009',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2500',
#   'סוג מנוע': 'טורבו דיזל',
#   'ק"מ': '300000',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'באר יעקב',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '55000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '24/07/2022',
#   'תאריך הקפצה אחרון': '24/07/2022',
#   'תיאור': 'הנטר מצב פצצה מנוע חדש טסט שנה מלאה'},
#  {'שנה': '2008',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2390',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '249000',
#   'אזור': 'נס ציונה - רחובות',
#   'עיר': 'רחובות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '32000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '21/07/2022',
#   'תאריך הקפצה אחרון': '21/07/2022',
#   'תיאור': 'דגם ספורט מפנק, כסאות מעור, חימום לכסאות, קילומטר נמוך ממוצע 10.000 בשנה. &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; סנרוף, מערכת שמע.'},
#  {'שנה': '2017',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1193',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '75000',
#   'אזור': 'רמת השרון - הרצליה',
#   'עיר': 'רמת השרון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '48000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '21/07/2022',
#   'תאריך הקפצה אחרון': '21/07/2022',
#   'תיאור': 'הרכב במצב מצוין'},
#  {'שנה': '2020',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2360',
#   'סוג מנוע': 'חשמלי',
#   'ק"מ': '122000',
#   'אזור': 'גליל ועמקים',
#   'עיר': 'נצרת',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '180000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '20/07/2022',
#   'תאריך הקפצה אחרון': '20/07/2022'},
#  {'שנה': '2011',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1499',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '250',
#   'אזור': 'ראש העין והסביבה',
#   'עיר': 'אלעד',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר הדור החדש',
#   'מחיר': '12500',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '18/07/2022',
# ...
#   'מספר תמונות': 1,
#   'תאריך יצירה': '20/06/2022',
#   'תאריך הקפצה אחרון': '20/06/2022',
#   'תיאור': 'אצלמו מ 2008 , ללא תאונות. אמין ושקט.'},
#  {'שנה': '2009',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1499',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '205000',
#   'אזור': 'נס ציונה - רחובות',
#   'עיר': 'מזכרת בתיה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר הדור החדש',
#   'מחיר': '10000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '17/06/2022',
#   'תאריך הקפצה אחרון': '17/06/2022',
#   'תיאור': 'מכנית-שמורה ומטופלת, ללא תקלות, ללא תאונות, טסט עד 8/22. חיצונית- שפשופי פגושים, אזורי צבע דהוי, 2 מכות קלות ביותר בפח. &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; ...'},
#  {'שנה': '2018',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1499',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '26000',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'גבעתיים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '116000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '09/06/2022',
#   'תאריך הקפצה אחרון': '09/06/2022',
#   'תיאור': 'דגם- אקליפס קרוס. תת דגם- אינסייט. עלתה לכביש בנובמבר 2018. במצב מעולה כחדשה. ללא תאונות.'},
#  {'שנה': '2011',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '224000',
#   'אזור': 'חדרה וישובי עמק חפר',
#   'עיר': 'חדרה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '37800',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '31/05/2022',
#   'תאריך הקפצה אחרון': '31/05/2022',
#   'תיאור': 'מיצובישי אאוטלנדר, בצבע לבן, יד שניה, 224000 קילומטרים. הרכב שמור. בלי תעונות. טסט עד 01.2023. מערכת מולטימדיה חדשנית עם אופציה ל-waze.'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '39000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '106000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '29/05/2022',
#   'תאריך הקפצה אחרון': '29/05/2022',
#   'תיאור': "מציאה**כמו חדש חדש**למכירה אאוטלנדר 2016 דגם אינטנס 5 מקומות צבע גרניט..רכב שמור ,חסכוני ושקט..קילומטראג' רק 38 אלף!! עבר 2 ידיים פרטיות..כולל תוספות של מערכת א..."},
#  {'שנה': '2008',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '125000',
#   'אזור': 'בקעת אונו',
#   'עיר': 'גני תקווה',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '27/05/2022',
#   'תאריך הקפצה אחרון': '27/05/2022',
#   'תיאור': 'רכב במצב מכני מצויין ושמור . מבחינת קוסמטיקה של הרכב ובפחחות הרכב לקוי צבע דאוי וכמה מכות פח . 125 אלף קמ'},
#  {'שנה': '2017',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '18000',
#   'אזור': 'פתח תקוה והסביבה',
#   'עיר': 'פתח תקווה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '130000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '24/05/2022',
#   'תאריך הקפצה אחרון': '24/05/2022',
#   'תיאור': 'דגם פרימיום המפואר 7 מושבים מעור מערכת מולטימדיה מצלמה אחורית וקדמית נהגת יחידה --18000 קילומטר בלבד--- בלי מכות בלי תאונות בלי שריטות אוטו במצב חדש &lt;br/&gt;...'},
#  {'שנה': '2018',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '19000',
#   'צבע': 'לבן פנינה',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'מושבים בשרון',
#   'עיר': 'אבן יהודה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '59000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '06/04/2022',
#   'תאריך הקפצה אחרון': '21/05/2022',
#   'תיאור': 'שמורה מאוד מטופלת ללא תאונות'},
#  {'שנה': '2017',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '30000',
#   'עיר': 'ראשון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '125000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '18/05/2022',
#   'תאריך הקפצה אחרון': '18/05/2022',
#   'תיאור': 'ללא תאונות צמיגים ומצבר חדשים מקוריים הוחלפו לא מזמן'},
#  {'שנה': '2015',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2200',
#   'סוג מנוע': 'דיזל',
#   'אזור': 'חולון - בת ים',
#   'עיר': 'אזור',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '85000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '10/05/2022',
#   'תאריך הקפצה אחרון': '10/05/2022',
#   'תיאור': 'אאוטלנד הדגם המפואר ביותר כולל כל התוספות! מושבי עור, בקרת שיוט, בלימה אוטונמית, מושב חשמלי , חימום מושבים ועןד ועוד'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1499',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '32900',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'רמת גן',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '124000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '09/05/2022',
#   'תאריך הקפצה אחרון': '09/05/2022',
#   'תיאור': 'רכב שני. ק"מ נמוך מטופל אצל היבואן. יימכר לאחר טיפול גדול. שווה! &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; דגם INTENSE'},
#  {'שנה': '2021',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1499',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '21563',
#   'עיר': 'Ashdod',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '145000',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '01/05/2022',
#   'תאריך הקפצה אחרון': '01/05/2022',
#   'תיאור': 'מיצובישי אקליפס דגם INSTY הרכב מטופל במוסך מורשה מיצובישי אשדוד לרכב יש טסט עד 01/23 &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; מראות חשמליות, גאנטים, גג נפתח, מ...'},
#  {'שנה': '2022',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1226',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '1500',
#   'אזור': 'חולון - בת ים',
#   'עיר': 'בת ים',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '27/04/2022',
#   'תאריך הקפצה אחרון': '27/04/2022',
#   'תיאור': 'רכב חדש מה ניילונים'},
#  {'שנה': '2015',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '36900',
#   'מספר תמונות': 1,
#   'תאריך יצירה': '18/04/2022',
#   'תאריך הקפצה אחרון': '18/04/2022',
#   'תיאור': 'לבוא לקחת. התחייבות לקנייה חוזרת עד 5 שנים. שקיפות מלאה!!! מגוון אפשרויות מימון עד 100% כולל תשלום בצקים. נמצא בסוכנות "גרינקאר" בראשל"צ, רח\' הרצל 28. הנחות ומח...'},
#  {'שנה': '2010',
#   'יד': '4',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '200000',
#   'צבע': 'אפור',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'אופקים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '17000',
#   'מספר תמונות': 7,
#   'תאריך יצירה': '17/11/2021',
#   'תאריך הקפצה אחרון': '17/11/2021',
#   'תיאור': 'מיצבושי לנסר החדשה'},
#  {'שנה': '2008',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '230000',
#   'צבע': 'אפור עכבר',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'טבריה והסביבה',
#   'עיר': 'טבריה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '6000',
#   'מספר תמונות': 10,
#   'תאריך יצירה': '15/10/2021',
#   'תאריך הקפצה אחרון': '15/10/2021',
#   'תיאור': 'מיצובישי לאנסר 2008 אוטמט 98 כ״ס יד 03 230 אלף ק״מ במצב מכאני מעולה במערכת מותקנת דיברוית ובלוטוס לשירים בס ורמקולים של פיוניר חלונות מושחרים אחוריים רכ...'},
#  {'שנה': '2008',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1800',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '176000',
#   'צבע': "בז'",
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'בני ברק',
#   'יצרן': 'מיצובישי',
#   'דגם': 'סופר לנסר',
#   'מחיר': '16500',
#   'מספר תמונות': 4,
#   'תאריך יצירה': '04/10/2021',
#   'תאריך הקפצה אחרון': '04/10/2021',
#   'תיאור': "רכב רחב ומפנק, קילומטרז' נמוך לגילו, ללא תאונות, מטופל בזמן."},
#  {'שנה': '2005',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1800',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '323000',
#   'צבע': 'כסוף',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '4500',
#   'תאריך יצירה': '29/09/2023',
#   'תאריך הקפצה אחרון': '29/09/2023',
#   'תיאור': "רכב תקין ללא שום בעיות. מזגן מקפיא! הושקע מולטימדיה יותר מ1000 שח טסט לעוד חצי שנה . מוכר בכ''כ זול משום שאני כבר לא משתמש עם הרכב"},
#  {'שנה': '2014',
#   'יד': '4',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '160000',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'ראשון לציון',
#   'יצרן': 'מיצובישי',
#   'דגם': "אטראז'",
#   'מחיר': '26000',
#   'תאריך יצירה': '29/10/2022',
#   'תאריך הקפצה אחרון': '29/10/2022',
#   'תיאור': 'רכב שמור מטופל בזמן ניראה כמו חדש מפתח חכם גמיש במחיר'},
#  {'שנה': '2008',
#   'יד': '5',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1584',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '152600',
#   'אזור': 'רמת גן - גבעתיים',
#   'עיר': 'בני ברק',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '13000',
#   'תאריך יצירה': '25/10/2022',
#   'תאריך הקפצה אחרון': '25/10/2022'},
#  {'שנה': '2012',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '130000',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר הדור החדש',
#   'מחיר': '25500',
#   'תאריך יצירה': '15/10/2022',
#   'תאריך הקפצה אחרון': '15/10/2022',
#   'תיאור': 'רכב שמור ומטופל טסט לשנה'},
#  {'שנה': '2010',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '295000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'נתיבות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר הדור החדש',
#   'מחיר': '14500',
#   'תאריך יצירה': '14/10/2022',
#   'תאריך הקפצה אחרון': '14/10/2022'},
#  {'שנה': '2009',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '3200',
#   'סוג מנוע': 'דיזל',
#   'ק"מ': '100000',
#   'צבע': 'לבן',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'חולון - בת ים',
#   'עיר': 'בת ים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'I-MIEV',
#   'מחיר': '95000',
#   'מספר תמונות': 2,
#   'תאריך יצירה': '15/05/2022',
#   'תאריך הקפצה אחרון': '15/05/2022',
#   'תיאור': 'הכול מקורי פנים וחוץ האותו 4X4 נפח 3200'},
#  {'שנה': '2016',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '128585',
#   'אזור': 'אשדוד - אשקלון',
#   'עיר': 'אשדוד',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '106500',
#   'תאריך יצירה': '27/09/2022',
#   'תאריך הקפצה אחרון': '27/09/2022',
#   'תיאור': 'מיצובישי אאוטלנדר 08/2016 יד 02 ליסינג תפעולי נהג יחיד לשעבר מנוע 1.99 בנזין 150 כס גימור אינסטייל: חלון בגג, מפתח חכם ועוד צבע כסף 7 מקומות תוספות: ...'},
#  {'שנה': '2021',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '6000',
#   'אזור': 'נתניה והסביבה',
#   'עיר': 'נתניה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '76000',
#   'תאריך יצירה': '27/09/2022',
#   'תאריך הקפצה אחרון': '27/09/2022',
#   'תיאור': 'רכב חדש של אדם מבוגר (אבא שלי) רק 6000 ק"מ, ללא שריטה , חונה תמיד בחניון מקורה מתחת לבניין נמכר עקב חוסר שימוש'},
#  {'שנה': '2007',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '318000',
#   'אזור': 'רעננה - כפר סבא',
#   'עיר': 'כפר סבא',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '3500',
#   'תאריך יצירה': '17/09/2022',
#   'תאריך הקפצה אחרון': '17/09/2022'},
#  {'שנה': '2015',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '185000',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין מכבים רעות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '70000',
#   'תאריך יצירה': '02/09/2022',
#   'תאריך הקפצה אחרון': '02/09/2022'},
#  {'שנה': '2016',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '122000',
#   'אזור': 'נתניה והסביבה',
#   'עיר': 'נתניה',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '990000',
#   'תאריך יצירה': '01/09/2022',
#   'תאריך הקפצה אחרון': '01/09/2022',
#   'תיאור': 'מיצובישי אאוטלנדר 7 מקומות מצב חדש אוטו שמור שמור'},
#  {'שנה': '2007',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '86000',
#   'עיר': 'תל אבי',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר קלאסיק',
#   'מחיר': '10000',
#   'תאריך יצירה': '27/08/2022',
#   'תאריך הקפצה אחרון': '27/08/2022'},
#  {'שנה': '2022',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '6000',
#   'אזור': 'עמק יזרעאל',
#   'עיר': 'קרית טבעון',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '240000',
#   'תאריך יצירה': '30/07/2022',
#   'תאריך הקפצה אחרון': '30/07/2022',
#   'תיאור': 'אאוטלנדר החדש דגם פרימיום 2022 יד ראשונה רכב חדש חדש עשה רק 6000 &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; ריפודי עור סנטטי רכב מבוקש מאוד ושמור כל הקודם זוכה...'},
#  {'שנה': '2021',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '15000',
#   'אזור': 'קריות',
#   'עיר': 'קרית ביאליק',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '210000',
#   'תאריך יצירה': '23/07/2022',
#   'תאריך הקפצה אחרון': '23/07/2022'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '10000',
#   'אזור': 'תל אביב',
#   'עיר': 'תל אביב יפו',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '150000',
#   'תאריך יצירה': '18/07/2022',
#   'תאריך הקפצה אחרון': '18/07/2022',
#   'תיאור': 'גג נפתח גם מאחורה'},
#  {'שנה': '2018',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '102000',
#   'אזור': 'ראשל"צ והסביבה',
#   'עיר': 'בית דגן',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ASX',
#   'מחיר': '90000',
#   'תאריך יצירה': '15/07/2022',
#   'תאריך הקפצה אחרון': '15/07/2022',
#   'תיאור': 'רכב שמור מטופל במוסכי מיטצובישי בלבד. לא עבור תאונות.יד פרטית.'},
#  {'שנה': '2019',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '69000',
#   'עיר': 'יקנעם עילית',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ASX',
#   'מחיר': '107000',
#   'תאריך יצירה': '14/07/2022',
#   'תאריך הקפצה אחרון': '14/07/2022',
#   'תיאור': 'שמורה מאד,מטופלת אך ורק במוסך מורשה ללא תאונות'},
#  {'שנה': '2007',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1600',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '162000',
#   'אזור': 'ירושלים והסביבה',
#   'עיר': 'ירושלים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר',
#   'מחיר': '6000',
#   'תאריך יצירה': '27/06/2022',
#   'תאריך הקפצה אחרון': '27/06/2022',
#   'תיאור': 'רכב מצוין,חסכוני,טסט בעוד חודש,מזגן מעולה,ישנם קילופי צבע, יד ראשונה היתה השכרה לא בשבת! &lt;br/&gt;&lt;br/&gt;פירוט:&lt;br/&gt; קודנית,בלוטוס,חיישני רוורס,גל...'},
#  {'שנה': '2017',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1998',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '122000',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין מכבים רעות',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '106000',
#   'תאריך יצירה': '22/05/2022',
#   'תאריך הקפצה אחרון': '22/05/2022',
#   'תיאור': 'מצב מצויין, שמור, כל הטיפולים בסוכנות מיצובישי/יונדאי מודיעין מתועדים. צמיגים חדשים, מצבר שנה וחצי. חלונות חשמלים, נעילה /פתיחה מרכזית מהשלט, מראות חשמליים.'},
#  {'שנה': '2020',
#   'יד': '1',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '16000',
#   'אזור': 'מודיעין והסביבה',
#   'עיר': 'מודיעין',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אקליפס',
#   'מחיר': '129000',
#   'תאריך יצירה': '11/05/2022',
#   'תאריך הקפצה אחרון': '11/05/2022',
#   'תיאור': 'רכב שמור נמצא בחניה מקורה נהג יחיד(70)'},
#  {'שנה': '2010',
#   'יד': '3',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1500',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '220000',
#   'אזור': 'קריות',
#   'עיר': 'רכסים',
#   'יצרן': 'מיצובישי',
#   'דגם': 'לנסר הדור החדש',
#   'מחיר': '11500',
#   'תאריך יצירה': '05/05/2022',
#   'תאריך הקפצה אחרון': '05/05/2022',
#   'תיאור': 'חלונות שחורים מסך באגז גדול מושבים יפים'},
#  {'שנה': '2017',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '2000',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '85000',
#   'אזור': 'באר שבע והסביבה',
#   'עיר': 'באר שבע',
#   'יצרן': 'מיצובישי',
#   'דגם': 'אאוטלנדר',
#   'מחיר': '115000',
#   'תאריך יצירה': '26/04/2022',
#   'תאריך הקפצה אחרון': '26/04/2022',
#   'תיאור': 'הרכב במצב מצויין טסט שלמה שלמה צלחות ברקסים וצמיגים חדשים טיפולצרק במוסך מורשה מלא תוספות זה דגם אינסטייל עם חלון בגג והנעה ללא מתפתח מראות מתקפלות ו...'},
#  {'שנה': '2015',
#   'יד': '2',
#   'ת. הילוכים': 'אוטומטית',
#   'נפח': '1200',
#   'סוג מנוע': 'בנזין',
#   'ק"מ': '100',
#   'צבע': 'כסוף מטאלי',
#   'בעלות קודמת': 'פרטית',
#   'בעלות נוכחית': 'פרטית',
#   'אזור': 'בית שמש והסביבה',
#   'עיר': 'בית שמש',
#   'יצרן': 'מיצובישי',
#   'דגם': 'ספייס סטאר',
#   'מחיר': '36000',
#   'תאריך יצירה': '13/01/2022',
#   'תאריך הקפצה אחרון': '13/01/2022',
#   'תיאור': 'נהגת יחידה. אוטו שני בבית.הרכב במצב חדשש. 4צמיגים חדשים .מצבר חדש .לאחר טיפול 100 אלף .חונה בחניה מקורה חסכוני מאוד שמור ומטופל ברמות כול הקודם זוכה'}]

# %%
# Convert the list of dictionaries to a DataFrame
scrape_df = pd.DataFrame(mitsu)


# Define the desired column order using key_mapping values
desired_columns = {
    'יצרן': 'manufactor',
    'שנה': 'Year',
    'דגם': 'model',
    'יד': 'Hand',
    'ת. הילוכים': 'Gear',
    'נפח': 'Engine_capacity',
    'סוג מנוע': 'Engine_type',
    'בעלות קודמת': 'Prev_ownership',
    'בעלות נוכחית': 'Curr_ownership',
    'אזור': 'Area',
    'עיר': 'City',
    'מחיר': 'Price',
    'מספר תמונות': 'Pic_num',
    'תאריך יצירה': 'Cre_date',
    'תאריך הקפצה אחרון': 'Repub_date',
    'תיאור': 'Description',
    'צבע': 'Color',
    'ק"מ': 'Km',
    'טסט עד': 'Test'
}
# Add 'Supply_score' column 
scrape_df['Supply_score'] = pd.NA

# Reindex the DataFrame to match the desired column order
scrape_df = scrape_df.reindex(columns=list(desired_columns.keys())+['Supply_score'])

# rename the columns to English
scrape_df.rename(columns=desired_columns, inplace=True)

# %% [markdown]
# #### Converting the types of the colunms

# %%
int_lst = ['Year','Hand','Engine_capacity','Pic_num','Km','Test','Supply_score']
str_lst = ['manufactor','model','Area','City','Description','Color']
date_lst = ['Cre_date','Repub_date']
cat_lst = ['Gear','Engine_type','Prev_ownership','Curr_ownership']

# %%
scrape_df[int_lst] = scrape_df[int_lst].apply(pd.to_numeric, errors='coerce').astype('Int64')
scrape_df["Price"] = scrape_df["Price"].apply(pd.to_numeric, errors='coerce').astype(float)
scrape_df[date_lst] = scrape_df[date_lst].apply(lambda x: pd.to_datetime(x, format='%d/%m/%Y', errors='coerce'))
scrape_df[str_lst] = scrape_df[str_lst].astype('str')
scrape_df[cat_lst] = scrape_df[cat_lst].astype('category')

# %%
scrape_df
# Out:
#     manufactor  Year           model  Hand      Gear  Engine_capacity  \
# 0     מיצובישי  2005     לנסר קלאסיק     8  אוטומטית             1600
# 1     מיצובישי  2016          GT3000     2  אוטומטית             2000
# 2     מיצובישי  2016          I-MIEV     2  אוטומטית             2000
# 3     מיצובישי  2020          אקליפס     2  אוטומטית             2000
# 4     מיצובישי  2010            לנסר     3  אוטומטית             1600
# ..         ...   ...             ...   ...       ...              ...
# 154   מיצובישי  2017        אאוטלנדר     1  אוטומטית             1998
# 155   מיצובישי  2020          אקליפס     1  אוטומטית             1500
# 156   מיצובישי  2010  לנסר הדור החדש     3  אוטומטית             1500
# 157   מיצובישי  2017        אאוטלנדר     2  אוטומטית             2000
# 158   מיצובישי  2015      ספייס סטאר     2  אוטומטית             1200
#
#     Engine_type Prev_ownership Curr_ownership             Area  \
# 0         בנזין          פרטית          פרטית  ירושלים והסביבה
# 1         בנזין          פרטית          פרטית  חיפה וחוף הכרמל
# 2         בנזין          פרטית          פרטית  חיפה וחוף הכרמל
# 3         בנזין         ליסינג          פרטית  חיפה וחוף הכרמל
# 4         בנזין          פרטית          פרטית    נתניה והסביבה
# ..          ...            ...            ...              ...
# 154       בנזין            NaN            NaN  מודיעין והסביבה
# 155       בנזין            NaN            NaN  מודיעין והסביבה
# 156       בנזין            NaN            NaN            קריות
# 157       בנזין            NaN            NaN  באר שבע והסביבה
# 158       בנזין          פרטית          פרטית  בית שמש והסביבה
#
#                    City     Price  Pic_num   Cre_date Repub_date  \
# 0               ירושלים    4700.0        3 2024-05-22 2024-05-27
# 1                   נשר   92000.0        4 2024-05-05 2024-05-05
# 2                   נשר   92000.0        4 2024-05-05 2024-05-04
# 3             טירת כרמל   85000.0        3 2024-04-25 2024-04-25
# 4                 נתניה   10000.0        7 2024-03-16 2024-03-16
# ..                  ...       ...      ...        ...        ...
# 154  מודיעין מכבים רעות  106000.0     <NA> 2022-05-22 2022-05-22
# 155             מודיעין  129000.0     <NA> 2022-05-11 2022-05-11
# 156               רכסים   11500.0     <NA> 2022-05-05 2022-05-05
# 157             באר שבע  115000.0     <NA> 2022-04-26 2022-04-26
# 158             בית שמש   36000.0     <NA> 2022-01-13 2022-01-13
#
#                                            Description       Color      Km  \
# 0    רכב במצב פצצה שירת אותי נאמנה הוחלף לפני חודש ...        כסוף  230000
# 1    אאוטלנדר המפואר פרמיום 7 מקומות טופל אצל היבוא...         לבן  141000
# 2    אאוטלנדר הדגם המפואר 7 מקומות שמור ומטופל אצל ...         לבן  141000
# 3              מיצובישי ASX 76,000 ק"מ מוכן גם להחליף.        שחור   76000
# 4    גיר מנוע תקינים מעככת מוביליין רכב 7 שנים עצלי...        כסוף  242000
# ..                                                 ...         ...     ...
# 154  מצב מצויין, שמור, כל הטיפולים בסוכנות מיצובישי...         nan  122000
# 155             רכב שמור נמצא בחניה מקורה נהג יחיד(70)         nan   16000
# 156            חלונות שחורים מסך באגז גדול מושבים יפים         nan  220000
# 157  הרכב במצב מצויין טסט שלמה שלמה צלחות ברקסים וצ...         nan   85000
# 158  נהגת יחידה. אוטו שני בבית.הרכב במצב חדשש. 4צמי...  כסוף מטאלי     100
#
#      Test  Supply_score
# 0     140          <NA>
# 1    <NA>          <NA>
# 2     260          <NA>
# 3     109          <NA>
# 4     170          <NA>
# ..    ...           ...
# 154  <NA>          <NA>
# 155  <NA>          <NA>
# 156  <NA>          <NA>
# 157  <NA>          <NA>
# 158  <NA>          <NA>
#
# [159 rows x 20 columns]

# %%
scrape_df.dtypes
# Out:
# manufactor                 object
# Year                        Int64
# model                      object
# Hand                        Int64
# Gear                     category
# Engine_capacity             Int64
# Engine_type              category
# Prev_ownership           category
# Curr_ownership           category
# Area                       object
# City                       object
# Price                     float64
# Pic_num                     Int64
# Cre_date           datetime64[ns]
# Repub_date         datetime64[ns]
# Description                object
# Color                      object
# Km                          Int64
# Test                        Int64
# Supply_score                Int64
# dtype: object

# %% [markdown]
# ### Getting Data from API

# %%
def fetch_filtered_data_from_api(api_url, resource_id, query, keys_to_extract, limit=1000):
    offset = 0
    all_records = []

    while True:
        # Construct the URL with limit, offset, and query parameters
        params = {
            'resource_id': resource_id,
            'limit': limit,
            'offset': offset,
            'q': query
        }
        url = f"{api_url}?{urllib.parse.urlencode(params)}"
        

        # Make a GET request to the API
        with urllib.request.urlopen(url) as response:
            if response.status == 200:
                data = json.loads(response.read().decode())
                
                # Check if the response contains the 'result' key
                if 'result' in data:
                    records = data['result']['records']
                    
                    if not records:
                        break
                    
                    # Filter the records to include only the specified keys
                    filtered_records = [
                        {key: record.get(key, 'NA') for key in keys_to_extract}
                        for record in records
                    ]
                    
                    # Add the filtered records to the all_records list
                    all_records.extend(filtered_records)
                    
                    # Update the offset for the next iteration
                    offset += limit
                else:
                    print("No 'result' key found in the API response.")
                    break
            else:
                print(f"Failed to fetch data from API. Status code: {response.status}")
                break

    return all_records
# Base URL for the API
api_url = 'https://data.gov.il/api/3/action/datastore_search'
    
# Resource ID for the dataset
resource_id = '5e87a7a1-2f6f-41c1-8aec-7216d52a6cf6'
    
# Query parameter for Mitsubishi vehicles
query = 'מיצובישי'
    
# Keys to extract from the API response
keys_to_extract = ['tozar', 'kinuy_mishari', 'shnat_yitzur']
    
# Fetch filtered data from the API
mitsu1 = fetch_filtered_data_from_api(api_url, resource_id, query, keys_to_extract)

# %%
mitsu1
# Out:
# [{'tozar': 'מיצובישי',
#   'kinuy_mishari': 'מיצובישי סופר לנסר I',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'מיצובישי סופר לנסר I',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'מיצובישי סופר לנסר I',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'מיצובישי סופר לנסר I',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'כריזמה 4דל LG', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'ספייס ואגון 4X4 אוטו',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה פרטי דיזל 4דל',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L-200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'פגרו קצר דיזל ידני',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה 6.1 RATS 4 דל',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'מיניבוס 004L', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'סופר לנסר ILG סלון',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'קומבי 004L', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': "כריזמה 6.1 XLG 4דלת'",
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'פגרו ארוך דיזל ידני',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט SLG 0002',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CARISMA', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': "כריזמה 6.1 XLG 4דלת'",
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה 4 דל LG',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUILANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'ספייס ואגון 4X4 אוטו',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'מיניבוס 004L', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': "כריזמה 6.1RATS 4דלת'",
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': "כריזמה 6.1 XLG 4דלת'",
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'חצי קומבי דיזל 1+6',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'סופר לנסר XLG דיזל',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'קומבי דיזל 2+6',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'סופר לנסר ILG סלון',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L300', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'סופר לנסר ILG סלון',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': '004-L מיניבוס בנזין',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L300', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'קומבי 004L', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'טנדר 002-L SLG דגם ב',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': '004-L קומבי דיזל ידנ',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'ספייס ראנר 4X4 ידני',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה 6.1 RATS 4דלת',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L-200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'קומבי 004L', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט SLG 0081',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה 4 דל LG',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': "כריזמה 6.1 XLG 4דלת'",
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CARISMA', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CANTER', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'טנדר 002-L SLG דגם א',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט SLG 0002',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'סופר לנסר ILG סלון',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L-200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2003},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2008},
# ...
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE WAGON', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'קומבי דיזל 2+8 אוטוב',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L300', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2001},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GALANT', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2000},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2002},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': '004-L קומבי דיזל ידנ',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'CARISMA', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט ISLG 0081',
#   'shnat_yitzur': 1996},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2008},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'ECLIPS CROSS PH',
#   'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'חצי קומבי דיזל 1+3',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'גאלנט ISLG 0081',
#   'shnat_yitzur': 1997},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'קומבי דיזל 1+3',
#   'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'GRANDIS', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2010},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUILANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER EVOLUTIO',
#   'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2009},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'LANCER SPORTBAC',
#   'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2004},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2006},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2012},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2021},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'כריזמה 9.1XLG דיזל 1',
#   'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 1999},
#  {'tozar': 'מיצובישי',
#   'kinuy_mishari': 'OUTLANDER PHEV',
#   'shnat_yitzur': 2019},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2005},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2024},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2013},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2015},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'LANCER', 'shnat_yitzur': 2007},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ASX', 'shnat_yitzur': 2020},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ATTRAGE', 'shnat_yitzur': 2018},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'COLT', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2014},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'ECLIPSE CROSS', 'shnat_yitzur': 2023},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'PAJERO', 'shnat_yitzur': 2017},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L 200', 'shnat_yitzur': 1998},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2016},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'L200', 'shnat_yitzur': 2022},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'OUTLANDER', 'shnat_yitzur': 2011},
#  {'tozar': 'מיצובישי', 'kinuy_mishari': 'SPACE STAR', 'shnat_yitzur': 2019},
#  ...]

# %% [markdown]
# ##### We are going to mapping the model values from mitsu1 to be suited to our main data (scrape_df)

# %%
kinuy_mishari_mappings = {
    'OUILANDER': 'אאוטלנדר',
    'OUTLANDER': 'אאוטלנדר',
    'LANCER': 'לנסר',
    'ECLIPSE CROSS': 'אקליפס',
    'SPACE STAR': 'ספייס סטאר',
    'LANCER EVOLUTIO': 'לנסר איוולושן',
    'LANCER SPORTBAC': 'לנסר ספורטבק',
    'GRANDIS': 'גרנדיס',
    'ATTRAGE': "אטראז'",
    'COLT': 'קולט',
    'מיצובישי סופר לנסר I': 'סופר לנסר',
    'סופר לנסר ILG סלון': 'סופר לנסר'
}

# %%
for record in mitsu1:
    kinuy_mishari = record.get('kinuy_mishari', '')
    if kinuy_mishari in kinuy_mishari_mappings:
        record['kinuy_mishari'] = kinuy_mishari_mappings[kinuy_mishari]

# %%
api_df = pd.DataFrame(mitsu1)

# %%
api_df
# Out:
#          tozar kinuy_mishari  shnat_yitzur
# 0     מיצובישי     סופר לנסר          1997
# 1     מיצובישי     סופר לנסר          1996
# 2     מיצובישי     סופר לנסר          1996
# 3     מיצובישי     סופר לנסר          1997
# 4     מיצובישי      אאוטלנדר          2008
# ...        ...           ...           ...
# 1602  מיצובישי           ASX          2021
# 1603  מיצובישי    ספייס סטאר          2013
# 1604  מיצובישי          L200          2014
# 1605  מיצובישי        אטראז'          2017
# 1606  מיצובישי      אאוטלנדר          2021
#
# [1607 rows x 3 columns]

# %%
agg_api_df = api_df.groupby(['tozar', 'kinuy_mishari', 'shnat_yitzur']).size().reset_index(name='Supply_score')

# %%
agg_api_df
# Out:
#         tozar         kinuy_mishari  shnat_yitzur  Supply_score
# 0    מיצובישי   004-L מיניבוס בנזין          1998             1
# 1    מיצובישי  004-L קומבי דיזל ידנ          1998             1
# 2    מיצובישי  004-L קומבי דיזל ידנ          1999             1
# 3    מיצובישי                   ASX          2011             2
# 4    מיצובישי                   ASX          2017             3
# ..        ...                   ...           ...           ...
# 260  מיצובישי        קומבי דיזל 1+3          1998             1
# 261  מיצובישי        קומבי דיזל 2+3          1998             1
# 262  מיצובישי        קומבי דיזל 2+6          1998             1
# 263  מיצובישי  קומבי דיזל 2+6 אוטוב          1998             1
# 264  מיצובישי  קומבי דיזל 2+8 אוטוב          1998             1
#
# [265 rows x 4 columns]

# %%
api_df.dtypes
# Out:
# tozar            object
# kinuy_mishari    object
# shnat_yitzur      int64
# dtype: object

# %% [markdown]
# ### Merging the 2 main DF - scrape_df & agg_api_df

# %%
agg_api_df.rename(columns={'kinuy_mishari': 'model', 'shnat_yitzur': 'Year'}, inplace=True)

# Merge DataFrames on the specified columns
merged_df = pd.merge(scrape_df, agg_api_df[['model', 'Year', 'Supply_score']], on=['model', 'Year'], how='left')

# Ensure Supply_score is Int64 
merged_df['Supply_score'] = merged_df['Supply_score_y'].fillna(merged_df['Supply_score_x']).astype('Int64')
merged_df.drop(columns=['Supply_score_x', 'Supply_score_y'], inplace=True)

# %%
merged_df.dtypes
# Out:
# manufactor                 object
# Year                        Int64
# model                      object
# Hand                        Int64
# Gear                     category
# Engine_capacity             Int64
# Engine_type              category
# Prev_ownership           category
# Curr_ownership           category
# Area                       object
# City                       object
# Price                     float64
# Pic_num                     Int64
# Cre_date           datetime64[ns]
# Repub_date         datetime64[ns]
# Description                object
# Color                      object
# Km                          Int64
# Test                        Int64
# Supply_score                Int64
# dtype: object

# %% [markdown]
# ### Slicing the Data between 2017-2024

# %%
mydf = merged_df[(merged_df['Year'] >= 2017) & (merged_df['Year'] <= 2024)]

# %%
mydf
# Out:
#     manufactor  Year         model  Hand      Gear  Engine_capacity  \
# 3     מיצובישי  2020        אקליפס     2  אוטומטית             2000
# 5     מיצובישי  2022        אקליפס     1  אוטומטית             1500
# 6     מיצובישי  2020  לנסר ספורטבק     2  אוטומטית             4200
# 7     מיצובישי  2020  לנסר ספורטבק     2  אוטומטית             4200
# 8     מיצובישי  2020  לנסר ספורטבק     2  אוטומטית             4200
# ..         ...   ...           ...   ...       ...              ...
# 151   מיצובישי  2018           ASX     1  אוטומטית             2000
# 152   מיצובישי  2019           ASX     1  אוטומטית             2000
# 154   מיצובישי  2017      אאוטלנדר     1  אוטומטית             1998
# 155   מיצובישי  2020        אקליפס     1  אוטומטית             1500
# 157   מיצובישי  2017      אאוטלנדר     2  אוטומטית             2000
#
#     Engine_type Prev_ownership Curr_ownership                 Area  \
# 3         בנזין         ליסינג          פרטית      חיפה וחוף הכרמל
# 5         בנזין          פרטית          פרטית    נס ציונה - רחובות
# 6            גז          פרטית          פרטית      באר שבע והסביבה
# 7            גז          פרטית          פרטית  חדרה וישובי עמק חפר
# 8            גז          פרטית          פרטית      באר שבע והסביבה
# ..          ...            ...            ...                  ...
# 151       בנזין            NaN            NaN       ראשל"צ והסביבה
# 152       בנזין            NaN            NaN                  nan
# 154       בנזין            NaN            NaN      מודיעין והסביבה
# 155       בנזין            NaN            NaN      מודיעין והסביבה
# 157       בנזין            NaN            NaN      באר שבע והסביבה
#
#                    City     Price  Pic_num   Cre_date Repub_date  \
# 3             טירת כרמל   85000.0        3 2024-04-25 2024-04-25
# 5                רחובות  129000.0        6 2024-02-06 2024-02-06
# 6               באר שבע   35000.0        4 2024-01-05 2024-01-05
# 7                  חדרה   35000.0        4 2024-01-05 2024-01-05
# 8                דימונה   35000.0        4 2024-01-05 2024-01-05
# ..                  ...       ...      ...        ...        ...
# 151             בית דגן   90000.0     <NA> 2022-07-15 2022-07-15
# 152         יקנעם עילית  107000.0     <NA> 2022-07-14 2022-07-14
# 154  מודיעין מכבים רעות  106000.0     <NA> 2022-05-22 2022-05-22
# 155             מודיעין  129000.0     <NA> 2022-05-11 2022-05-11
# 157             באר שבע  115000.0     <NA> 2022-04-26 2022-04-26
#
#                                            Description       Color      Km  \
# 3              מיצובישי ASX 76,000 ק"מ מוכן גם להחליף.        שחור   76000
# 5    דגם executive מנוע 1.5 טורבו מפתח חכם כניסה וה...  כחול מטאלי   21500
# 6    2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנ...         לבן   90000
# 7    2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנ...         לבן   90000
# 8    2020 מיצובישי אאוטלנדר ספורט ES 4x4 1-בעלים מנ...         לבן   90000
# ..                                                 ...         ...     ...
# 151  רכב שמור מטופל במוסכי מיטצובישי בלבד. לא עבור ...         nan  102000
# 152     שמורה מאד,מטופלת אך ורק במוסך מורשה ללא תאונות         nan   69000
# 154  מצב מצויין, שמור, כל הטיפולים בסוכנות מיצובישי...         nan  122000
# 155             רכב שמור נמצא בחניה מקורה נהג יחיד(70)         nan   16000
# 157  הרכב במצב מצויין טסט שלמה שלמה צלחות ברקסים וצ...         nan   85000
#
#      Test  Supply_score
# 3     109            15
# 5    <NA>            15
# 6    <NA>          <NA>
# 7    <NA>          <NA>
# 8    <NA>          <NA>
# ..    ...           ...
# 151  <NA>             5
# 152  <NA>             6
# 154  <NA>            26
# 155  <NA>            15
# 157  <NA>            26
#
# [74 rows x 20 columns]

# %% [markdown]
# ### Export to CSV File

# %%
mydf.to_csv('mitsu17_24.csv',encoding='utf-8-sig',index=False)
